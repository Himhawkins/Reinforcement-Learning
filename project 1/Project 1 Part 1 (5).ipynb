# %% [markdown]
# # Perform a looping with a quadrotor

# %% [markdown]
# # Goal of the project
#
# The goal of this project is to control a 2D quadrotor to get it to perform acrobatic moves. The controller will be designed using an SQP solver.
#
# Please submit your code as a runnable Jupyter Notebook.
#
# ## 2D quadrotor
#
# The quadrotor is depicted in the following figure
# <img src='quadrotor.png' width="300">
#
#
# The quadrotor model is written as
# $$\begin{align}
# \dot{p_x} &= v_x\\
# m \dot{v}_x &= - (u_1 + u_2) \sin \theta \\
# \dot{p_y} &= v_y\\
# m \dot{v}_y &= (u_1 + u_2) \cos \theta  - m g\\
# \dot{\theta} &= \omega\\
# I \dot{\omega} &= r (u_1 - u_2) \end{align}$$
# where $p_x$ is the horizontal and $p_y$ the vertical positions of the quadrotor and $\theta$ is its orientation with respect to the horizontal plane. $v_x$ and $v_y$ are the linear velocities and $\omega$ is the angular velocity of the robot. $u_1$ and $u_2$ are the forces produced by the rotors (our control inputs). $m$ is the quadrotor mass, $I$ its moment of inertia (a scalar), $r$ is the distance from the center of the robot frame to the propellers and $g$ is the gravity constant. To denote the entire state, we will write $x = [p_x, v_x, p_y, v_y, \theta, \omega]^T$ - we will also write $u = [u_1, u_2]^T$.
#
# The module ```quadrotor.py``` defines the problem and provides all the useful information about the robot and methods to simulate and animate it as shown below.
#
# You can access the different parameters of the model in the following way:

# %%
import quadrotor

print("Mass    =", quadrotor.MASS)
print("Length  =", quadrotor.LENGTH)
print("Inertia =", quadrotor.INERTIA)
print("Dt      =", quadrotor.DT)
print("state size   =", quadrotor.DIM_STATE)
print("control size =", quadrotor.DIM_CONTROL)
# Out:
# Mass    = 0.45
# Length  = 0.14
# Inertia = 0.09
# Dt      = 0.04
# state size   = 6
# control size = 2

# %% [markdown]
# ## Part 1 - Setting up the trajectory optimization problem (50 points)
# 1. Discretize the system dynamics using Euler's method seen in class - write the time discretization step as $\Delta t$ (use symbols not numbers for the mass, etc)
# 2. We would like the quadrotor to perfom a looping (i.e. a back or front flip). Find and implement a suitable cost function to perform a looping and add constraints to maintain the thrust of each rotor between $0$ and $10$. Solve the problem using your own implementation of a SQP with a long horizon to ensure that you can do a looping.
# 3. Show plots of all the states and controls of the robot as a function of time. Plot the value of $\alpha$ (during line search) at each iteration of the solver as well as the amount of constraint viol per iteration and the cost per iteration of the solver (also useful to help you debug).
# 5. Describe your design choices (in a concise manner) in the report.
#
# To visualize the trajectory, use the ```quadrotor.animate_robot``` function and show the animation (show the plots in your report).
#
# ### Tips to implement a SQP solver
# 1. Write down the algorithm (in words not in code), i.e. write all the steps you need to take
# 2. Write the gradient of the run cost at a given guess $\bar{x} = [{\bar{p}_x}_0, {\bar{v}_x}_0, {\bar{p}_y}_0, {\bar{v}_{y}}_0, \bar{\theta}_0, \bar{\omega}_0, {\bar{u}_1}_0, {\bar{u}_2}_0, \dots, {\bar{p}_x}_N, {\bar{v}_x}_N, {\bar{p}_y}_N, {\bar{v}_{y}}_N, \bar{\theta}_N, \bar{\omega}_N, {\bar{u}_1}_N, {\bar{u}_2}_N,]^T$, i.e. for a given value of these variables and implement a function that computes it
# 3. Write the Hessian of the run cost at a given guess $\bar{x}$ and implement a function that computes it
# 4. Assume that the Hessian of the constraints is 0 (i.e. ignore the second order derivatives of the constraints)
# 5. Write a linear approximation of the constraints at a given guess $\bar{x}$ in a form $G(\bar{x}) \Delta x = g(\bar{x})$ (don't forget the constant terms in g) where $\Delta x$ represents a small variation around $\bar{x}$ and implement a function that computes both $G$ and $g$.
# 6. Use these functions to setup the inner QP of the SQP (use the library from HW2 to solve the QP).
# 7. Implement a function that computes the amount of constraint viol for the nonlinear constraints (not the linearized one), i.e. the sum of the absolute values of all the constraints (i.e. assuming constraints of the form $c(x) = 0$ we want to compute $|c(x)|$).
# 8. Implement a filter linear search to test if a step should be accepted. You will implement the (simplified) filter line search explained below.
# 9. Terminate the algorithm when you either reached the maximum number of iterations (e.g. 100) or when the KKT optimality conditions are satisfied (within a small margin, e.g. $10^{-4}$).
#
# Once you have a solution, make sure to check that it satisfies the constraints! You can display the robot using the ```animate_robot``` function.
#
# #### (Simple) filter linear search
# Once you have a potential step $\textrm{step}_x$, you need to find a step $\alpha$ to update your guess of the solution $x_{guess}$. We will accept a step that either reduces the amount of constraint viol or reduces the cost.
#
# Let's denote $f(x)$ the cost at $x$ and $|c(x)|$ the amount of constraint viol at $x$. Initialize the variable $f_{best} = \infty$ and $c_{best}=\infty$ at the beginning of the SQP.
#
# Then do the following during the line search.
# 1. Set $\rho$ to a number between 0 and 1 (e.g. 0.5) and set $\alpha = 1$
# 2. If $f(x_{guess} + \alpha \textrm{step}_x) < f_{best}$ then set $f_{best} \leftarrow f(x_{guess} + \alpha \textrm{step}_x)$ and accept the step
#
#    Or
#
#    If $|c(x_{guess} + \alpha \textrm{step}_x)| < c_{best}$ then set $c_{best} \leftarrow |c(x_{guess} + \alpha \textrm{step}_x)|$ and accept the step
# 3. If the step was not accepted set $\alpha \leftarrow \rho \alpha$ and go back to Step 2.
# 4. If the step was accepted update the guess $x_{guess} \leftarrow x_{guess} + \alpha \textrm{step}_x$
#
# ## Part 2 - Model predictive control (MPC) (50 points)
# 1. Use the trajectory optimization method from Part I to design a MPC controller and test it using the simulator below (you may need to use a shorter horizon). In particular, verify that it can handle perturbations by calling the ```quadrotor.simulate``` function with ```disturbance = True``` (when setting disturbance to True, the simulator will generate a random perturbation every 1 second). Simulate your controller for 10 seconds, plot the state anc control evolution.
# 2. Explain your intended design in the report, including the cost function and found control law
#
# The ```quadrotor.simulate``` function takes as an input an initial state, a controller, the number of discrete time steps and a boolean value to indicate the presence of perturbation. The controller has to be a function taking as an input a state and time index and outputting a control vector.

# %% [markdown]
# ## Bonus (10 points)
# Add a state constraint to perform the looping while maintening a positive altitude. Use the origin as an initial state.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.animation as animation
import IPython

def controller(x, t):
    return np.zeros(2)

x_init = np.array([0, 0, 0., 0 ,0, 0])
horizon_length = 100
t, state, u = quadrotor.simulate(x_init, controller, horizon_length, disturbance=True)
quadrotor.animate_robot(state, u)
# Out:
# <video width="850" height="850" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
## write down your code here
import numpy as np
import quadrotor
from quadrotor import next_state
from qpsolvers import solve_qp
import matplotlib.pyplot as plt

def get_cost_matrix_G(Q,R,Qf):
    G = np.zeros((nvars, nvars))
    for i in range(N):
        # state cost (x_n)
        idx_x = i * (xdim + udim)
        G[idx_x:(idx_x + xdim), idx_x:(idx_x + xdim)] = Q
        
        # control cost (u_n)
        idx_u = idx_x + xdim
        G[idx_u:(idx_u + udim), idx_u:(idx_u + udim)] = R
    idx_xN = (N)*(xdim + udim)
    G[idx_xN:(idx_xN + xdim), idx_xN:(idx_xN + xdim)] = Qf
    return G

def calc_cost_grad(Z_guess,Q,R,Qf,x_target):
    g = np.zeros(nvars)
    x = np.zeros((xdim,N + 1))
    u = np.zeros((udim,N))
    for n in range(N):
        idx_x = (n)*(xdim + udim)
        x[:,n] = Z_guess[idx_x:(idx_x + xdim)]
        u[:,n] = Z_guess[(idx_x + xdim):(idx_x+xdim+udim)] 
    x[:, N] = Z_guess[N*(xdim+udim):N*(xdim+udim)+xdim]
    for n in range(N):
        idx_x = n*(xdim+udim) 
        idx_u = idx_x + xdim      
        g[idx_x:(idx_x+xdim)] = Q @ x[:,n]
        g[idx_u:(idx_u+udim)] = R @ u[:,n]
    g[N*(xdim+udim):N*(xdim+udim) + xdim] = Qf @ (x[:,N] - x_target) 
    return g

def calc_A(x_n, u_n):
    px = x_n[0]
    vx = x_n[1]
    py = x_n[2]
    vy = x_n[3]
    theta = x_n[4]
    w = x_n[5]
    u1 = u_n[0]
    u2 = u_n[1]
    grad_dx = np.zeros((xdim, xdim))
    
    grad_dx[0,1] = 1.0 
    grad_dx[1,4] = -(u1 + u2)*(np.cos(theta))/quadrotor.MASS 
    grad_dx[2,3] = 1.0 
    grad_dx[3,4] = -(u1 + u2)*(np.sin(theta))/quadrotor.MASS 
    grad_dx[4,5] = 1.0 
    grad_dx[5,:]  = [0,0,0,0,0,0]
    A_n = np.eye(xdim) + (quadrotor.DT)*(grad_dx) 
    return A_n
    
def calc_B(x_n, u_n):
    px = x_n[0]
    vx = x_n[1]
    py = x_n[2]
    vy = x_n[3]
    theta = x_n[4]
    w = x_n[5]
    u1 = u_n[0]
    u2 = u_n[1]
    grad_du = np.zeros((xdim, udim))
    
    grad_du[0,:] = [0,0]
    grad_du[1,0] = -(np.sin(theta))/quadrotor.MASS
    grad_du[1,1] = -(np.sin(theta))/quadrotor.MASS
    grad_du[2,:] = [0,0]
    grad_du[3,0] = np.cos(theta)/quadrotor.MASS
    grad_du[3,1] = np.cos(theta)/quadrotor.MASS
    grad_du[4,:] = [0,0]
    grad_du[5,0] = quadrotor.LENGTH/quadrotor.INERTIA
    grad_du[5,1] = -(quadrotor.LENGTH)/quadrotor.INERTIA
    B_n = quadrotor.DT * grad_du 
    return B_n

def build_M_and_p(Z_guess,x_init):
    n_constr = (N + 1)*(xdim)
    M = np.zeros((n_constr,nvars))
    p = np.zeros(n_constr)
    x = np.zeros((xdim,N + 1))
    u = np.zeros((udim,N))
    
    idx_xN = (N)*(xdim + udim) 
    for n in range(N):
        idx_x = (n)*(xdim + udim)
        idx_u = idx_x + xdim
        x[:,n] = Z_guess[idx_x:(idx_x + xdim)]
        u[:,n] = Z_guess[idx_u:(idx_u + udim)]
    x[:,N] = Z_guess[idx_xN:(idx_xN + xdim)]
    M[0:xdim,0:xdim] = np.eye(xdim)
    p[0:xdim] = x_init.flatten()
    
    for n in range(N):
        x_n = x[:,n]
        u_n = u[:,n]
        x_n_p1 = x[:,n+1]
        x_np1_pred = next_state(x_n,u_n)
        A_n = calc_A(x_n,u_n)
        B_n = calc_B(x_n,u_n)
        
        row_idx_start = (n+1)*(xdim)
        row_idx_end   = (n+2)*(xdim)
        col_idx_xn   = (n)*(xdim + udim)
        col_idx_un   = col_idx_xn + xdim
        col_idx_xn_1 = (n + 1)*(xdim + udim)

        M[row_idx_start:row_idx_end,col_idx_xn:col_idx_un]       = A_n
        M[row_idx_start:row_idx_end, col_idx_un:(col_idx_un+udim)]   = B_n
        M[row_idx_start:row_idx_end,col_idx_xn_1:(col_idx_xn_1+xdim)] = -(np.eye(xdim))
        
        p[row_idx_start:row_idx_end] = x_n_p1 - x_np1_pred 
    return M, p

def init_Guess(x_init):
    Z_guess = np.zeros(nvars)
    x_guess = np.zeros((xdim, N + 1))
    u_guess = np.zeros((udim, N))
    x_guess[:,0] = x_init
    
    # First Control Guess
    u_hover = np.array([(quadrotor.MASS)*(quadrotor.GRAVITY_CONSTANT)/2.0, (quadrotor.MASS)*(quadrotor.GRAVITY_CONSTANT)/2.0])
    for n in range(N):
        u_guess[:, n] = u_hover
        x_guess[:, n+1] = next_state(x_guess[:, n], u_guess[:, n])   
    # Pack into Z_guess
    for n in range(N):
        idx_x = (n)*(xdim + udim)
        idx_u = idx_x + xdim
        Z_guess[idx_x:(idx_x + xdim)] = x_guess[:, n]
        Z_guess[idx_u:(idx_u + udim)] = u_guess[:, n]
    idx_xN = N*(xdim + udim)
    Z_guess[idx_xN:(idx_xN + xdim)] = x_guess[:, N]
    return Z_guess

def NLCostViol(Z,Q,R,Qf,x_target,x_init):
    x = np.zeros((xdim,N + 1))
    u = np.zeros((udim,N))
    for n in range(N):
        idx_x = n*(xdim + udim)
        x[:,n] = Z[idx_x:(idx_x + xdim)]
        u[:,n] = Z[(idx_x + xdim):(idx_x + xdim + udim)]
    idx_xN = N*(xdim + udim)
    x[:, N] = Z[idx_xN:(idx_xN + xdim)]

    cost = 0.0
    for n in range(N):
        cost += 0.5*(x[:,n].T @ Q @ x[:,n] + u[:,n].T @ R @ u[:,n])
    cost += (0.5)*(x[:,N]-x_target).T @ Qf @ (x[:,N]-x_target)
    viol = 0.0
    viol += np.sum(np.abs(x[:,0] - x_init))
    for n in range(N):
        x_np1_pred = next_state(x[:,n], u[:, n])
        viol += np.sum(np.abs(x_np1_pred - x[:, n+1]))
    for n in range(N):
        viol += np.sum(np.maximum(0,u[:,n] - u_max))
        viol += np.sum(np.maximum(0,u_min - u[:,n]))
    epsilon = 1e-4
    for n in range(N + 1):
        viol += np.sum(np.maximum(0, -x[2, n] - epsilon))
    return cost, viol

def line_search(Z_k, dZ, cost_k, viol_k):
    global f_best, c_best
    alpha = 1.0
    rho = 0.5
    for i in range(100):
        Z_new = Z_k + (alpha)*(dZ)
        cost_new, viol_new = NLCostViol(Z_new,Q_run,R_run,Qf,x_target,x_init)
        if (cost_new<f_best)or(viol_new<c_best):
            if cost_new < f_best:
                f_best = cost_new
            if viol_new < c_best:
                c_best = viol_new
            return alpha,cost_new,viol_new
        alpha = alpha*rho
    return 0.0, cost_k, viol_k

def extract_Sol(Z):
    x_sol = np.zeros((xdim,N + 1))
    u_sol = np.zeros((udim,N))
    for i in range(N):
        idx_x = i*(xdim+udim)
        x_sol[:,i] = Z[idx_x:(idx_x+xdim)]
        u_sol[:,i] = Z[(idx_x+xdim):(idx_x+xdim+udim)]
    x_sol[:,N] = Z[N*(xdim+udim):N*(xdim+udim)+xdim]
    return x_sol, u_sol
#-----------------------------------------
xdim = quadrotor.DIM_STATE 
udim = quadrotor.DIM_CONTROL 
x_init = np.zeros(xdim) 
x_target = np.array([0,0,0,0,2*np.pi,0]) 
N = 100 
nvars = (N*udim) + ((N+1)*xdim)
u_max = np.array([10.0,10.0])
u_min = np.array([0.0,0.0]) 
Q_run = np.diag([20.0,0.1,70.0,0.1,0,0.1])
Qf = np.diag([1000,10,1000,10,10000,100])
R_run = np.eye(udim)*0.375
f_best = float('inf')
c_best = float('inf')

max_iter = 100
convg_tol = 1e-4
G = get_cost_matrix_G(Q_run,R_run,Qf)
n_ineq_ctrl = 4*N     
n_ineq_state = N + 1     
n_ineq = n_ineq_ctrl + n_ineq_state

H = np.zeros((n_ineq, nvars)) 
Z_guess = init_Guess(x_init)
cost_k, viol_k = NLCostViol(Z_guess,Q_run,R_run, Qf, x_target, x_init)

if cost_k < f_best: 
    f_best = cost_k
if viol_k < c_best: 
    c_best = viol_k
    
print(f"1st Guess: Cost={cost_k:.4f}, viol={viol_k:.4f}")

costs_per_iter = [cost_k]
viols_per_iter = [viol_k]
alphas_per_iter = []

# SQP
for k in range(max_iter):
    g = calc_cost_grad(Z_guess,Q_run,R_run,Qf,x_target)
    M, p = build_M_and_p(Z_guess,x_init)
    
    x_guess, u_guess = extract_Sol(Z_guess)
    h = np.zeros(n_ineq)
    row_idx = 0
    for n in range(N):
        idx_u1 = n*(xdim + udim) + xdim
        idx_u2 = idx_u1 + 1
        H[row_idx,idx_u1] = 1.0  
        H[row_idx + 1,idx_u2] = 1.0  
        H[row_idx + 2,idx_u1] = -1.0 
        H[row_idx + 3,idx_u2] = -1.0
        row_idx += 4
    row_idx = 0
    for n in range(N):
        h[row_idx]     = u_max[0] - u_guess[0,n] 
        h[row_idx + 1] = u_max[1] - u_guess[1,n] 
        h[row_idx + 2] = u_guess[0, n] - u_min[0] 
        h[row_idx + 3] = u_guess[1, n] - u_min[1] 
        row_idx += 4
    epsilon = 1e-4
    for n in range(N + 1):
        idx_xn_2 = n * (xdim + udim) + 2 
        H[row_idx, idx_xn_2] = -1.0      
        h[row_idx] = x_guess[2, n] + epsilon 
        row_idx += 1
    dZ = solve_qp(G,g.flatten(),H,h,M,p,solver='cvxopt')
        
    alpha, cost_k, viol_k = line_search(Z_guess,dZ,cost_k,viol_k)
    alphas_per_iter.append(alpha)
    costs_per_iter.append(cost_k)
    viols_per_iter.append(viol_k)
    
    if alpha == 0.0:
        break 
    Z_guess = Z_guess + (alpha)*(dZ)
    step = np.linalg.norm(alpha * dZ)
    print(f"Iter {k+1:02d}: Cost ={cost_k:.4f}, Viol ={viol_k:.4f}, Step ={step:.4f}, Alpha ={alpha:.4f}")
    
    if step < convg_tol and viol_k < (convg_tol*(N + 1)):
        print("\nConverged")
        break

x_sol, u_sol = extract_Sol(Z_guess)
x_ref_full = x_sol      # from Part 1
u_ref_full = u_sol
print("Final Cost:", cost_k)
print("Final Viol:", viol_k)
quadrotor.animate_robot(x_sol,u_sol)
time_states = np.arange(N+1)*quadrotor.DT
time_controls = np.arange(N)*quadrotor.DT

# State and Control Plots
plt.figure(figsize=(12,10))
plt.suptitle("State and Control Trajectories", fontsize=16)
state_labels = ['x-p','x-v','y-p','y-v','Angle','Ang v']
for i in range(6):
    plt.subplot(4,2, i+1)
    plt.plot(time_states, x_sol[i, :])  
    plt.ylabel(state_labels[i])
    plt.xlabel('Time (s)')
    plt.grid(True)
plt.subplot(4, 2, 7)
plt.plot(time_controls, u_sol[0,:], label='u1')
plt.plot(time_controls, u_sol[1,:], label='u2')
plt.ylabel('Thrust (N)')
plt.xlabel('Time (s)')
plt.grid(True)
plt.legend()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

plt.figure(figsize=(6, 6))
plt.plot(x_sol[0, :], x_sol[2, :])
plt.title('Flip Shape (x vs y)')
plt.xlabel('x-position (m)')
plt.ylabel('y-position (m)')
plt.axhline(0, color='r', linestyle='--', label='y=0')
plt.legend()
plt.axis('equal')
plt.grid(True)
plt.show()

plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)
plt.plot(costs_per_iter)
plt.title('Cost per Iteration')
plt.xlabel('Iteration')
plt.ylabel('Cost (J)')
plt.grid(True)

plt.subplot(1, 3, 2)
plt.plot(viols_per_iter)
plt.title('Viol per Iteration')
plt.xlabel('Iteration')
plt.ylabel('Viol Norm (|c|)')
plt.yscale('log') 
plt.grid(True)

plt.subplot(1, 3, 3)
plt.plot(alphas_per_iter, 'o-')
plt.title('Alpha per Iteration')
plt.xlabel('Iteration')
plt.ylabel('Step Size (alpha)')
plt.ylim(0, 1.1)
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 1st Guess: Cost=197574.7862, viol=0.0000
# Iter 01: Cost =4953.9750, Viol =36.6987, Step =66.8794, Alpha =1.0000
# Iter 02: Cost =1455.7443, Viol =11.4056, Step =53.8384, Alpha =1.0000
# Iter 03: Cost =1151.7271, Viol =1.0366, Step =19.4232, Alpha =1.0000
# Iter 04: Cost =1044.8500, Viol =1.0079, Step =11.2259, Alpha =1.0000
# Iter 05: Cost =991.2562, Viol =0.3198, Step =8.3071, Alpha =1.0000
# Iter 06: Cost =962.7550, Viol =0.1903, Step =6.4591, Alpha =1.0000
# Iter 07: Cost =948.2465, Viol =0.1061, Step =4.5453, Alpha =1.0000
# Iter 08: Cost =939.2632, Viol =0.0612, Step =3.4201, Alpha =1.0000
# Iter 09: Cost =934.6868, Viol =0.0287, Step =2.5614, Alpha =1.0000
# Iter 10: Cost =932.3452, Viol =0.0165, Step =1.8399, Alpha =1.0000
# Iter 11: Cost =930.8535, Viol =0.0129, Step =1.5044, Alpha =1.0000
# Iter 12: Cost =929.6685, Viol =0.0132, Step =1.5482, Alpha =1.0000
# Iter 13: Cost =928.4736, Viol =0.0115, Step =1.4805, Alpha =1.0000
# Iter 14: Cost =927.5511, Viol =0.0078, Step =1.3638, Alpha =1.0000
# Iter 15: Cost =926.9175, Viol =0.0053, Step =1.1409, Alpha =1.0000
# Iter 16: Cost =926.4724, Viol =0.0023, Step =0.7896, Alpha =1.0000
# Iter 17: Cost =926.3200, Viol =0.0004, Step =0.3659, Alpha =1.0000
# Iter 18: Cost =926.2965, Viol =0.0001, Step =0.1828, Alpha =1.0000
# Iter 19: Cost =926.2905, Viol =0.0000, Step =0.0938, Alpha =1.0000
# Iter 20: Cost =926.2890, Viol =0.0000, Step =0.0470, Alpha =1.0000
# Iter 21: Cost =926.2886, Viol =0.0000, Step =0.0237, Alpha =1.0000
# Iter 22: Cost =926.2885, Viol =0.0000, Step =0.0119, Alpha =1.0000
# Iter 23: Cost =926.2885, Viol =0.0000, Step =0.0060, Alpha =1.0000
# Iter 24: Cost =926.2884, Viol =0.0000, Step =0.0030, Alpha =1.0000
# Iter 25: Cost =926.2884, Viol =0.0000, Step =0.0015, Alpha =1.0000
# Iter 26: Cost =926.2884, Viol =0.0000, Step =0.0008, Alpha =1.0000
# Iter 27: Cost =926.2884, Viol =0.0000, Step =0.0004, Alpha =1.0000
# Iter 28: Cost =926.2884, Viol =0.0000, Step =0.0002, Alpha =1.0000
# Iter 29: Cost =926.2884, Viol =0.0000, Step =0.0001, Alpha =1.0000
#
# Converged
# Final Cost: 926.288442314276
# Final Viol: 2.5236081567712706e-11
# <video width="850" height="850" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import numpy as np
import quadrotor
from quadrotor import next_state
from qpsolvers import solve_qp
from scipy.linalg import solve_discrete_are
import matplotlib.pyplot as plt
import time


N_mpc = 30                     # horizon length requested
R_stage = 0.01 * np.eye(quadrotor.DIM_CONTROL)
sqp_iters_per_step = 5        # SQP iters per MPC step (RTI-style)
eps_reg = 1e-8                 # Hessian regularization for QP
line_search_max = 6
alpha_rho = 0.5


xdim = quadrotor.DIM_STATE
udim = quadrotor.DIM_CONTROL
u_eq = np.array([quadrotor.MASS * quadrotor.GRAVITY_CONSTANT / 2.0,
                 quadrotor.MASS * quadrotor.GRAVITY_CONSTANT / 2.0])
u_min = np.array([0.0, 0.0])
u_max = np.array([10.0, 10.0])


def pack_from_traj(x_traj, u_traj, Nloc):
    nvars = (Nloc * udim) + ((Nloc + 1) * xdim)
    Z = np.zeros(nvars)
    for n in range(Nloc):
        idx_x = n * (xdim + udim)
        idx_u = idx_x + xdim
        Z[idx_x: idx_x + xdim] = x_traj[:, n]
        Z[idx_u: idx_u + udim] = u_traj[:, n]
    idx_xN = Nloc * (xdim + udim)
    Z[idx_xN: idx_xN + xdim] = x_traj[:, Nloc]
    return Z

def unpack_Z(Z, Nloc):
    expected_len = (Nloc * udim) + ((Nloc + 1) * xdim)
    if Z.size != expected_len:
        raise ValueError(f"unpack_Z: Z has size {Z.size} but expected {expected_len} for Nloc={Nloc}")
    x = np.zeros((xdim, Nloc + 1))
    u = np.zeros((udim, Nloc))
    for n in range(Nloc):
        idx_x = n * (xdim + udim)
        x[:, n] = Z[idx_x: idx_x + xdim]
        u[:, n] = Z[idx_x + xdim: idx_x + xdim + udim]
    idx_xN = Nloc * (xdim + udim)
    x[:, Nloc] = Z[idx_xN: idx_xN + xdim]
    return x, u

if 'x_sol' in globals() and 'u_sol' in globals():
    x_ref_full = x_sol.copy()
    u_ref_full = u_sol.copy()
elif 'x_ref_full' in globals() and 'u_ref_full' in globals():
    x_ref_full = x_ref_full.copy()
    u_ref_full = u_ref_full.copy()


pad_multiplier = 4
pad_len = int(pad_multiplier * N_mpc)
x_ref_padded = np.hstack([x_ref_full, np.tile(x_ref_full[:, -1].reshape(-1, 1), (1, pad_len))])
if u_ref_full.shape[1] > 0:
    u_ref_padded = np.hstack([u_ref_full, np.tile(u_ref_full[:, -1].reshape(-1, 1), (1, pad_len))])
else:
    u_ref_padded = np.tile(u_eq.reshape(-1, 1), (1, pad_len))

def get_ref_state(idx_global):
    idx = int(idx_global)
    idx = min(idx, x_ref_padded.shape[1] - 1)
    return x_ref_padded[:, idx]

def get_ref_control(idx_global):
    idx = int(idx_global)
    idx = min(idx, u_ref_padded.shape[1] - 1)
    return u_ref_padded[:, idx]


A_hover = calc_A(np.zeros(xdim), u_eq)
B_hover = calc_B(np.zeros(xdim), u_eq)
R_stage_mat = R_stage if isinstance(R_stage, np.ndarray) else np.eye(udim) * float(R_stage)
P_terminal = solve_discrete_are(A_hover, B_hover,
                                np.diag([200.0, 5.0, 200.0, 5.0, 1000.0, 50.0]),
                                R_stage_mat)
K_lqr = np.linalg.inv(R_stage_mat + B_hover.T @ P_terminal @ B_hover) @ (B_hover.T @ P_terminal @ A_hover)

def lqr_fallback_u(x):
    dx = x - np.zeros(xdim)
    du = -K_lqr @ dx
    ucmd = u_eq + du
    return np.clip(ucmd, u_min, u_max)

# ------------------ Warm-start persistence & helpers ------------------
try:
    prev_Zwarm
except NameError:
    prev_Zwarm = None

def shift_prev_Zwarm(prev_Zwarm_in):
    if prev_Zwarm_in is None:
        return None
    shift = xdim + udim
    if prev_Zwarm_in.size != (N_mpc * udim + (N_mpc + 1) * xdim):
        # If stored warm isn't same size, discard it
        return None
    Znew = np.zeros_like(prev_Zwarm_in)
    if prev_Zwarm_in.size > shift:
        Znew[:-shift] = prev_Zwarm_in[shift:]
        Znew[-shift:] = prev_Zwarm_in[-shift:]
    else:
        Znew[:] = prev_Zwarm_in.copy()
    return Znew

def warm_start_from_ref(idx_global):
    x_w = np.zeros((xdim, N_mpc + 1))
    u_w = np.zeros((udim, N_mpc))
    for k in range(N_mpc + 1):
        x_w[:, k] = get_ref_state(idx_global + k)
    for k in range(N_mpc):
        u_w[:, k] = get_ref_control(idx_global + k)
    u_w = np.clip(u_w, u_min.reshape(-1, 1), u_max.reshape(-1, 1))
    return pack_from_traj(x_w, u_w, N_mpc)

def track_cost_and_viol(Z, idx_global, Q_stage_local, R_stage_local, Qf_local):
    x, u = unpack_Z(Z, N_mpc)
    cost = 0.0
    viol = 0.0
    for k in range(N_mpc):
        x_ref_k = get_ref_state(idx_global + k)
        u_ref_k = get_ref_control(idx_global + k)
        dx = x[:, k] - x_ref_k
        du = u[:, k] - u_ref_k
        cost += 0.5 * (dx.T @ Q_stage_local @ dx + du.T @ R_stage_local @ du)
        x_np1_pred = next_state(x[:, k], u[:, k])
        viol += np.sum(np.abs(x_np1_pred - x[:, k + 1]))
        # broadcasting-safe control bounds violation
        viol += np.sum(np.maximum(0.0, u[:, k] - u_max.reshape(-1, 1)))
        viol += np.sum(np.maximum(0.0, u_min.reshape(-1, 1) - u[:, k]))
    xN_ref = get_ref_state(idx_global + N_mpc)
    dxN = x[:, N_mpc] - xN_ref
    cost += 0.5 * (dxN.T @ Qf_local @ dxN)
    eps = 1e-6
    viol += np.sum(np.maximum(0.0, -x[2, :] - eps))
    return cost, float(viol)

def build_local_G(Q_stage_local, R_stage_local, Qf_local):
    nvars_local = (N_mpc * udim) + ((N_mpc + 1) * xdim)
    G = np.zeros((nvars_local, nvars_local))
    for i in range(N_mpc):
        idx_x = i * (xdim + udim)
        idx_u = idx_x + xdim
        G[idx_x:idx_x + xdim, idx_x:idx_x + xdim] = Q_stage_local
        G[idx_u:idx_u + udim, idx_u:idx_u + udim] = R_stage_local
    idx_xN = N_mpc * (xdim + udim)
    G[idx_xN:idx_xN + xdim, idx_xN:idx_xN + xdim] = Qf_local
    return G

def build_local_M_p(Z_guess):
    n_constr = (N_mpc + 1) * xdim
    M = np.zeros((n_constr, Z_guess.size))
    p = np.zeros(n_constr)
    xg, ug = unpack_Z(Z_guess, N_mpc)
    M[0:xdim, 0:xdim] = np.eye(xdim)
    for n in range(N_mpc):
        x_n = xg[:, n].copy()
        u_n = ug[:, n].copy()
        x_np1 = xg[:, n + 1].copy()
        x_np1_pred = next_state(x_n, u_n)
        A_n = calc_A(x_n, u_n)
        B_n = calc_B(x_n, u_n)
        row_start = (n + 1) * xdim
        row_end = (n + 2) * xdim
        col_xn = n * (xdim + udim)
        col_un = col_xn + xdim
        col_xn1 = (n + 1) * (xdim + udim)
        M[row_start:row_end, col_xn:col_xn + xdim] = A_n
        M[row_start:row_end, col_un:col_un + udim] = B_n
        M[row_start:row_end, col_xn1:col_xn1 + xdim] = -np.eye(xdim)
        p[row_start:row_end] = x_np1 - x_np1_pred
    return M, p

def build_local_H_h(Z_guess):
    n_ineq = 4 * N_mpc + (N_mpc + 1)
    H = np.zeros((n_ineq, Z_guess.size))
    h = np.zeros(n_ineq)
    xg, ug = unpack_Z(Z_guess, N_mpc)
    row = 0
    for n in range(N_mpc):
        idx_u1 = n * (xdim + udim) + xdim
        idx_u2 = idx_u1 + 1
        H[row, idx_u1] = 1.0
        H[row + 1, idx_u2] = 1.0
        H[row + 2, idx_u1] = -1.0
        H[row + 3, idx_u2] = -1.0
        h[row] = u_max[0] - ug[0, n]
        h[row + 1] = u_max[1] - ug[1, n]
        h[row + 2] = ug[0, n] - u_min[0]
        h[row + 3] = ug[1, n] - u_min[1]
        row += 4
    eps = 1e-6
    for n in range(N_mpc + 1):
        if n < N_mpc:
            idx_xn_2 = n * (xdim + udim) + 2
        else:
            idx_xn_2 = N_mpc * (xdim + udim) + 2
        H[row, idx_xn_2] = -1.0
        h[row] = xg[2, n] + eps
        row += 1
    return H, h

def kkt_fallback(Gloc, gvec, M, p):
    n = Gloc.shape[0]
    m = M.shape[0]
    reg = 1e-8
    A_kkt = np.block([[Gloc + reg * np.eye(n), M.T],
                      [M, np.zeros((m, m))]])
    rhs = -np.concatenate([gvec.flatten(), p.flatten()])
    try:
        sol = np.linalg.solve(A_kkt, rhs)
        dZ = sol[:n]
        return dZ
    except np.linalg.LinAlgError:
        return None

def make_nmpc_controller():
    global prev_Zwarm
    Q_stage = np.diag([80.0, 50.0, 80.0, 50.0, 800.0, 200.0])   # emphasize angle & omega
    Qf_stage = np.diag([400.0, 40.0, 400.0, 40.0, 2000.0, 300.0])
    R_stage_local = R_stage_mat

    def controller(x_current, t_idx):
        global prev_Zwarm
        idx_global = int(t_idx)

        # warm start (shifted previous or reference)
        if prev_Zwarm is None:
            Z_guess = np.zeross(N_mpc*8) #warm_start_from_ref(idx_global)
        else:
            Z_guess = shift_prev_Zwarm(prev_Zwarm)
            if Z_guess is None:
                Z_guess = warm_start_from_ref(idx_global)

        # enforce measured current state
        Z_guess[0:xdim] = x_current

        # build local Hessian and small reg
        Gloc = build_local_G(Q_stage, R_stage_local, Qf_stage)
        Gloc += eps_reg * np.eye(Gloc.shape[0])

        # initial merit/cost/viol
        # try:
        #     cost_k, viol_k = track_cost_and_viol(Z_guess, idx_global, Q_stage, R_stage_local, Qf_stage)
        # except ValueError:
        #     # if Z_guess malformed for any reason, regenerate warm start and re-evaluate
        #     Z_guess = warm_start_from_ref(idx_global)
        #     Z_guess[0:xdim] = x_current
        #     cost_k, viol_k = track_cost_and_viol(Z_guess, idx_global, Q_stage, R_stage_local, Qf_stage)
        Z_work = Z_guess.copy()

        # SQP iterations
        for it in range(sqp_iters_per_step):
            cost_k, viol_k =np.inf, np.inf
            xg, ug = unpack_Z(Z_work, N_mpc)
            gvec = np.zeros(Gloc.shape[0])
            for k in range(N_mpc):
                idx_x = k * (xdim + udim)
                idx_u = idx_x + xdim
                x_ref_k = get_ref_state(idx_global + k)
                u_ref_k = get_ref_control(idx_global + k)
                gvec[idx_x:idx_x + xdim] = Q_stage @ (xg[:, k] - x_ref_k)
                gvec[idx_u:idx_u + udim] = R_stage_local @ (ug[:, k] - u_ref_k)
            idx_xN = N_mpc * (xdim + udim)
            xN_ref = get_ref_state(idx_global + N_mpc)
            gvec[idx_xN: idx_xN + xdim] = Qf_stage @ (xg[:, N_mpc] - xN_ref)

            Mloc, ploc = build_local_M_p(Z_work)
            # ploc[0:xdim] =  x_current
            Hloc, hloc = build_local_H_h(Z_work)

            # QP: solve for dZ
            try:
                dZ = solve_qp(Gloc, gvec.flatten(), Hloc, hloc, Mloc, ploc, solver='cvxopt')
            except Exception:
                dZ = None

            if dZ is None:
                print("Solver NONE BREAKING")
                break
                # dZ = kkt_fallback(Gloc, gvec, Mloc, ploc)
                # if dZ is None:
                    # fallback to safe LQR action
                    
                    # prev_Zwarm = None
                    # return lqr_fallback_u(x_current)

            # line search on nonlinear merit
            accepted = False
            alpha = 1.0
            
            for ls in range(line_search_max):
                Z_cand = Z_work + alpha * dZ
                try:
                    cost_cand, viol_cand = track_cost_and_viol(Z_cand, idx_global, Q_stage, R_stage_local, Qf_stage)
                except ValueError:
                    # improper candidate size -> shrink step
                    cost_cand, viol_cand = np.inf, np.inf
                if (cost_cand < cost_k) or (viol_cand < viol_k):
                    Z_work = Z_cand
                    cost_k, viol_k = cost_cand, viol_cand
                    accepted = True
                    break
                alpha *= alpha_rho
            if (not accepted) and (it == 0):
                prev_Zwarm = None
                return lqr_fallback_u(x_current)
            if np.linalg.norm(alpha * dZ) < 1e-3:
                break

        # extract and return first control, clamp for safety
        x_final, u_final = unpack_Z(Z_work, N_mpc)
        u_first = np.clip(u_final[:, 0], u_min, u_max)

        # update warm
        prev_Zwarm = shift_prev_Zwarm(Z_work)

        # telemetry
        print(f"[NMPC] t={t_idx}, u_first=[{u_first[0]:.3f}, {u_first[1]:.3f}], angle={x_current[4]:.3f}, ang_vel={x_current[5]:.3f}, cost={cost_k:.3e}, viol={viol_k:.3e}")
        return u_first

    return controller


mpc_ctrl = make_nmpc_controller()

x0 = get_ref_state(0).copy()
sim_steps = int(10.0 / quadrotor.DT)  # 10 seconds
t0 = time.time()
try:
    t_mpc, state_mpc, u_mpc = quadrotor.simulate(x0, mpc_ctrl, sim_steps, True)
except TypeError:
    t_mpc, state_mpc, u_mpc = quadrotor.simulate(z0=x0, controller=mpc_ctrl, horizon_length=sim_steps, disturbance=True)
t1 = time.time()
print(f"Simulation done in {t1 - t0:.2f} s")

# animate and plot
quadrotor.animate_robot(state_mpc, u_mpc)

time_states_mpc = np.arange(state_mpc.shape[1]) * quadrotor.DT
time_controls_mpc = np.arange(u_mpc.shape[1]) * quadrotor.DT
time_ref = np.arange(x_ref_padded.shape[1]) * quadrotor.DT

plt.figure(figsize=(14, 10))
plt.suptitle("NMPC - Tracking Reference Trajectory (with Disturbances)", fontsize=16)
state_labels = ['x-pos (m)', 'x-vel (m/s)', 'y-pos (m)', 'y-vel (m/s)', 'Angle (rad)', 'Ang vel (rad/s)']
for i in range(6):
    plt.subplot(4, 2, i + 1)
    plt.plot(time_states_mpc, state_mpc[i, :], label='NMPC', linewidth=2)
    ref_len = min(len(time_ref), len(time_states_mpc))
    plt.plot(time_ref[:ref_len], x_ref_padded[i, :ref_len], '--', alpha=0.7, label='Reference' if i == 0 else "")
    plt.ylabel(state_labels[i]); plt.xlabel('Time (s)')
    plt.grid(True)
    if i == 0: plt.legend()

plt.subplot(4, 2, 7)
plt.plot(time_controls_mpc, u_mpc[0, :], label='NMPC u1', alpha=0.8)
plt.plot(time_controls_mpc, u_mpc[1, :], label='NMPC u2', alpha=0.8)
ref_u_len = min(u_ref_padded.shape[1], u_mpc.shape[1])
plt.plot(time_ref[:ref_u_len], u_ref_padded[0, :ref_u_len], '--', alpha=0.5, label='Ref u1')
plt.plot(time_ref[:ref_u_len], u_ref_padded[1, :ref_u_len], '--', alpha=0.5, label='Ref u2')
plt.ylabel('Thrust (N)'); plt.xlabel('Time (s)'); plt.grid(True); plt.legend()
plt.tight_layout(rect=[0, 0.03, 1, 0.95]); plt.show()

plt.figure(figsize=(8, 8))
plt.plot(state_mpc[0, :], state_mpc[2, :], linewidth=2, label='NMPC Actual')
plt.plot(x_ref_padded[0, :], x_ref_padded[2, :], '--', linewidth=2, alpha=0.7, label='Reference')
plt.scatter(x0[0], x0[2], color='g', s=80, marker='o', label='Start', zorder=5)
plt.title('NMPC Trajectory Tracking (x vs y)'); plt.xlabel('x-position (m)'); plt.ylabel('y-position (m)')
plt.axhline(0, color='k', linestyle='--', alpha=0.3); plt.legend(); plt.grid(True); plt.axis('equal'); plt.show()
# Out:
# [NMPC] t=0, u_first=[2.168, 2.249], angle=-0.000, ang_vel=0.000, cost=4.316e-03, viol=1.715e-02
# [NMPC] t=1, u_first=[5.697, 0.000], angle=-0.000, ang_vel=-0.000, cost=5.097e+02, viol=9.653e-07
# [NMPC] t=2, u_first=[0.222, 0.000], angle=-0.000, ang_vel=0.354, cost=5.024e+02, viol=1.050e-07
# [NMPC] t=3, u_first=[0.822, 0.000], angle=0.014, ang_vel=0.368, cost=4.790e+02, viol=3.563e-08
# [NMPC] t=4, u_first=[1.394, 2.718], angle=0.029, ang_vel=0.419, cost=4.577e+02, viol=9.252e-08
# [NMPC] t=5, u_first=[2.173, 3.537], angle=0.046, ang_vel=0.337, cost=4.289e+02, viol=1.309e-09
# [NMPC] t=6, u_first=[2.197, 3.357], angle=0.059, ang_vel=0.252, cost=4.050e+02, viol=2.276e-10
# [NMPC] t=7, u_first=[2.215, 3.051], angle=0.069, ang_vel=0.179, cost=3.872e+02, viol=2.653e-10
# [NMPC] t=8, u_first=[1.820, 2.607], angle=0.076, ang_vel=0.127, cost=3.731e+02, viol=5.700e-10
# [NMPC] t=9, u_first=[1.993, 2.679], angle=0.081, ang_vel=0.078, cost=3.610e+02, viol=2.314e-10
# [NMPC] t=10, u_first=[2.094, 2.646], angle=0.085, ang_vel=0.036, cost=3.502e+02, viol=7.463e-11
# [NMPC] t=11, u_first=[2.098, 2.526], angle=0.086, ang_vel=0.001, cost=3.403e+02, viol=2.345e-11
# [NMPC] t=12, u_first=[2.107, 2.420], angle=0.086, ang_vel=-0.025, cost=3.309e+02, viol=1.003e-11
# [NMPC] t=13, u_first=[2.123, 2.330], angle=0.085, ang_vel=-0.045, cost=3.219e+02, viol=4.388e-12
# [NMPC] t=14, u_first=[2.144, 2.254], angle=0.083, ang_vel=-0.058, cost=3.131e+02, viol=1.700e-12
# [NMPC] t=15, u_first=[2.169, 2.190], angle=0.081, ang_vel=-0.064, cost=3.045e+02, viol=3.624e-11
# [NMPC] t=16, u_first=[2.197, 2.137], angle=0.078, ang_vel=-0.066, cost=2.958e+02, viol=1.819e-11
# [NMPC] t=17, u_first=[2.226, 2.093], angle=0.076, ang_vel=-0.062, cost=2.873e+02, viol=9.393e-12
# [NMPC] t=18, u_first=[2.255, 2.059], angle=0.073, ang_vel=-0.054, cost=2.787e+02, viol=5.666e-12
# [NMPC] t=19, u_first=[2.284, 2.033], angle=0.071, ang_vel=-0.042, cost=2.702e+02, viol=3.714e-12
# [NMPC] t=20, u_first=[2.310, 2.015], angle=0.069, ang_vel=-0.026, cost=2.616e+02, viol=2.425e-12
# [NMPC] t=21, u_first=[2.334, 2.005], angle=0.068, ang_vel=-0.008, cost=2.531e+02, viol=1.440e-12
# [NMPC] t=22, u_first=[2.355, 2.004], angle=0.068, ang_vel=0.013, cost=2.445e+02, viol=8.821e-13
# [NMPC] t=23, u_first=[2.371, 2.009], angle=0.069, ang_vel=0.035, cost=2.359e+02, viol=5.974e-13
# [NMPC] t=24, u_first=[2.380, 2.019], angle=0.070, ang_vel=0.057, cost=2.274e+02, viol=9.353e-10
# [NMPC] t=25, u_first=[2.382, 2.035], angle=0.072, ang_vel=0.080, cost=2.189e+02, viol=8.389e-10
# [NMPC] t=26, u_first=[4.588, 0.000], angle=0.075, ang_vel=0.007, cost=7.916e+02, viol=1.287e-06
# [NMPC] t=27, u_first=[0.531, 0.000], angle=0.076, ang_vel=0.293, cost=7.713e+02, viol=1.406e-07
# [NMPC] t=28, u_first=[1.605, 0.000], angle=0.087, ang_vel=0.326, cost=7.540e+02, viol=3.488e-07
# [NMPC] t=29, u_first=[1.296, 0.000], angle=0.100, ang_vel=0.425, cost=7.447e+02, viol=5.658e-07
# [NMPC] t=30, u_first=[0.996, 0.524], angle=0.118, ang_vel=0.506, cost=7.351e+02, viol=3.641e-08
# [NMPC] t=31, u_first=[1.840, 3.020], angle=0.138, ang_vel=0.535, cost=7.209e+02, viol=9.322e-09
# [NMPC] t=32, u_first=[2.273, 3.417], angle=0.159, ang_vel=0.462, cost=6.999e+02, viol=5.731e-09
# [NMPC] t=33, u_first=[2.189, 3.312], angle=0.178, ang_vel=0.391, cost=6.815e+02, viol=2.313e-09
# [NMPC] t=34, u_first=[2.096, 3.228], angle=0.193, ang_vel=0.321, cost=6.658e+02, viol=8.783e-10
# [NMPC] t=35, u_first=[2.006, 3.170], angle=0.206, ang_vel=0.250, cost=6.514e+02, viol=3.113e-10
# [NMPC] t=36, u_first=[1.918, 3.132], angle=0.216, ang_vel=0.178, cost=6.374e+02, viol=1.473e-10
# [NMPC] t=37, u_first=[1.833, 3.109], angle=0.223, ang_vel=0.103, cost=6.231e+02, viol=1.079e-10
# [NMPC] t=38, u_first=[1.749, 3.097], angle=0.227, ang_vel=0.023, cost=6.083e+02, viol=7.184e-11
# [NMPC] t=39, u_first=[1.667, 3.090], angle=0.228, ang_vel=-0.061, cost=5.927e+02, viol=4.125e-11
# [NMPC] t=40, u_first=[1.589, 3.086], angle=0.226, ang_vel=-0.149, cost=5.764e+02, viol=2.119e-11
# [NMPC] t=41, u_first=[1.516, 3.079], angle=0.220, ang_vel=-0.242, cost=5.594e+02, viol=1.023e-11
# [NMPC] t=42, u_first=[1.447, 3.063], angle=0.210, ang_vel=-0.340, cost=5.419e+02, viol=4.260e-12
# [NMPC] t=43, u_first=[1.384, 3.036], angle=0.197, ang_vel=-0.440, cost=5.238e+02, viol=2.021e-12
# [NMPC] t=44, u_first=[1.324, 2.995], angle=0.179, ang_vel=-0.543, cost=5.054e+02, viol=1.067e-10
# [NMPC] t=45, u_first=[1.309, 2.963], angle=0.157, ang_vel=-0.647, cost=4.861e+02, viol=6.037e-11
# [NMPC] t=46, u_first=[1.390, 3.004], angle=0.131, ang_vel=-0.750, cost=4.668e+02, viol=4.880e-11
# [NMPC] t=47, u_first=[1.481, 3.012], angle=0.101, ang_vel=-0.850, cost=4.474e+02, viol=5.596e-11
# [NMPC] t=48, u_first=[1.585, 2.981], angle=0.067, ang_vel=-0.946, cost=4.281e+02, viol=4.547e-11
# [NMPC] t=49, u_first=[1.704, 2.907], angle=0.030, ang_vel=-1.033, cost=4.090e+02, viol=3.099e-11
# [NMPC] t=50, u_first=[1.834, 2.784], angle=-0.012, ang_vel=-1.107, cost=3.901e+02, viol=9.476e-12
# [NMPC] t=51, u_first=[0.000, 0.000], angle=-0.056, ang_vel=-1.471, cost=5.241e+02, viol=1.018e-09
# [NMPC] t=52, u_first=[0.000, 0.000], angle=-0.115, ang_vel=-1.471, cost=4.634e+02, viol=4.947e-10
# [NMPC] t=53, u_first=[0.735, 0.000], angle=-0.174, ang_vel=-1.471, cost=4.159e+02, viol=1.406e-09
# [NMPC] t=54, u_first=[3.105, 0.950], angle=-0.233, ang_vel=-1.425, cost=3.691e+02, viol=4.332e-09
# [NMPC] t=55, u_first=[3.738, 1.832], angle=-0.289, ang_vel=-1.291, cost=3.170e+02, viol=2.899e-10
# [NMPC] t=56, u_first=[3.798, 1.323], angle=-0.341, ang_vel=-1.172, cost=2.702e+02, viol=5.790e-10
# [NMPC] t=57, u_first=[3.970, 0.838], angle=-0.388, ang_vel=-1.018, cost=2.312e+02, viol=6.567e-10
# [NMPC] t=58, u_first=[4.179, 0.421], angle=-0.429, ang_vel=-0.823, cost=1.986e+02, viol=4.689e-10
# [NMPC] t=59, u_first=[4.384, 0.426], angle=-0.462, ang_vel=-0.589, cost=1.715e+02, viol=1.239e-10
# [NMPC] t=60, u_first=[4.558, 0.375], angle=-0.485, ang_vel=-0.343, cost=1.491e+02, viol=4.286e-12
# [NMPC] t=61, u_first=[4.729, 0.308], angle=-0.499, ang_vel=-0.083, cost=1.308e+02, viol=1.418e-10
# [NMPC] t=62, u_first=[4.866, 0.000], angle=-0.502, ang_vel=0.192, cost=1.155e+02, viol=1.671e-10
# [NMPC] t=63, u_first=[5.095, 0.000], angle=-0.495, ang_vel=0.495, cost=1.024e+02, viol=4.401e-13
# [NMPC] t=64, u_first=[5.287, 0.000], angle=-0.475, ang_vel=0.812, cost=9.088e+01, viol=3.834e-13
# [NMPC] t=65, u_first=[5.428, 0.000], angle=-0.442, ang_vel=1.141, cost=8.052e+01, viol=3.121e-13
# [NMPC] t=66, u_first=[5.493, 0.000], angle=-0.397, ang_vel=1.479, cost=7.112e+01, viol=1.671e-13
# [NMPC] t=67, u_first=[5.455, 0.000], angle=-0.337, ang_vel=1.821, cost=6.255e+01, viol=9.534e-14
# [NMPC] t=68, u_first=[5.296, 0.000], angle=-0.265, ang_vel=2.160, cost=5.471e+01, viol=3.583e-11
# [NMPC] t=69, u_first=[5.013, 0.000], angle=-0.178, ang_vel=2.490, cost=4.756e+01, viol=2.297e-11
# [NMPC] t=70, u_first=[4.668, 0.000], angle=-0.079, ang_vel=2.802, cost=4.088e+01, viol=1.104e-11
# [NMPC] t=71, u_first=[8.486, 0.000], angle=0.033, ang_vel=3.092, cost=3.809e+01, viol=7.959e-12
# [NMPC] t=72, u_first=[9.766, 0.000], angle=0.157, ang_vel=3.620, cost=4.130e+01, viol=9.903e-12
# [NMPC] t=73, u_first=[9.757, 0.000], angle=0.302, ang_vel=4.228, cost=5.129e+01, viol=2.230e-11
# [NMPC] t=74, u_first=[9.425, 0.000], angle=0.471, ang_vel=4.835, cost=6.849e+01, viol=5.015e-11
# [NMPC] t=75, u_first=[9.702, 1.877], angle=0.664, ang_vel=5.421, cost=9.315e+01, viol=1.194e-10
# [NMPC] t=76, u_first=[4.214, 0.000], angle=0.881, ang_vel=5.802, cost=2.483e+02, viol=7.198e-10
# [NMPC] t=77, u_first=[8.774, 0.000], angle=1.113, ang_vel=6.064, cost=2.403e+02, viol=4.077e-10
# [NMPC] t=78, u_first=[5.471, 0.000], angle=1.356, ang_vel=6.610, cost=2.736e+02, viol=2.213e-13
# [NMPC] t=79, u_first=[0.609, 0.000], angle=1.620, ang_vel=6.951, cost=3.225e+02, viol=2.745e-10
# [NMPC] t=80, u_first=[1.048, 0.000], angle=1.898, ang_vel=6.989, cost=3.788e+02, viol=4.659e-10
# [NMPC] t=81, u_first=[1.223, 0.000], angle=2.178, ang_vel=7.054, cost=4.434e+02, viol=5.329e-10
# [NMPC] t=82, u_first=[1.164, 0.442], angle=2.460, ang_vel=7.130, cost=5.158e+02, viol=9.928e-10
# [NMPC] t=83, u_first=[0.000, 1.307], angle=2.745, ang_vel=7.175, cost=5.953e+02, viol=2.553e-09
# [NMPC] t=84, u_first=[0.000, 0.690], angle=3.032, ang_vel=7.094, cost=6.819e+02, viol=2.726e-09
# [NMPC] t=85, u_first=[0.000, 0.187], angle=3.316, ang_vel=7.051, cost=7.781e+02, viol=3.046e-12
# [NMPC] t=86, u_first=[0.000, 0.124], angle=3.598, ang_vel=7.039, cost=8.836e+02, viol=2.858e-11
# [NMPC] t=87, u_first=[0.000, 0.026], angle=3.880, ang_vel=7.031, cost=9.987e+02, viol=5.216e-11
# [NMPC] t=88, u_first=[0.000, 0.000], angle=4.161, ang_vel=7.030, cost=1.123e+03, viol=3.044e-11
# [NMPC] t=89, u_first=[0.000, 5.163], angle=4.442, ang_vel=7.030, cost=1.257e+03, viol=4.043e-09
# [NMPC] t=90, u_first=[0.000, 9.831], angle=4.723, ang_vel=6.708, cost=1.400e+03, viol=2.016e-11
# [NMPC] t=91, u_first=[0.000, 9.826], angle=4.992, ang_vel=6.097, cost=1.547e+03, viol=2.186e-11
# [NMPC] t=92, u_first=[0.000, 9.824], angle=5.235, ang_vel=5.485, cost=1.702e+03, viol=3.149e-11
# [NMPC] t=93, u_first=[0.000, 9.827], angle=5.455, ang_vel=4.874, cost=1.865e+03, viol=3.391e-11
# [NMPC] t=94, u_first=[0.000, 9.840], angle=5.650, ang_vel=4.263, cost=2.036e+03, viol=5.181e-11
# [NMPC] t=95, u_first=[0.000, 9.873], angle=5.820, ang_vel=3.650, cost=2.216e+03, viol=1.210e-10
# [NMPC] t=96, u_first=[0.000, 9.939], angle=5.966, ang_vel=3.036, cost=2.406e+03, viol=3.015e-10
# [NMPC] t=97, u_first=[0.000, 10.000], angle=6.088, ang_vel=2.418, cost=2.606e+03, viol=6.712e-10
# [NMPC] t=98, u_first=[0.000, 10.000], angle=6.184, ang_vel=1.795, cost=2.816e+03, viol=2.118e-09
# [NMPC] t=99, u_first=[0.000, 9.747], angle=6.256, ang_vel=1.173, cost=3.036e+03, viol=4.244e-08
# [NMPC] t=100, u_first=[0.000, 3.235], angle=6.303, ang_vel=0.567, cost=3.265e+03, viol=4.901e-08
# [NMPC] t=101, u_first=[4.650, 3.730], angle=6.326, ang_vel=0.549, cost=4.216e+03, viol=8.438e-07
# [NMPC] t=102, u_first=[1.749, 3.319], angle=6.348, ang_vel=0.607, cost=4.515e+03, viol=1.246e-07
# [NMPC] t=103, u_first=[2.563, 3.476], angle=6.372, ang_vel=0.509, cost=4.838e+03, viol=2.664e-07
# [NMPC] t=104, u_first=[1.815, 2.626], angle=6.392, ang_vel=0.452, cost=5.172e+03, viol=1.356e-07
# [NMPC] t=105, u_first=[1.730, 2.720], angle=6.410, ang_vel=0.402, cost=5.515e+03, viol=6.401e-07
# [NMPC] t=106, u_first=[1.728, 2.890], angle=6.427, ang_vel=0.340, cost=5.864e+03, viol=4.911e-07
# [NMPC] t=107, u_first=[2.401, 3.398], angle=6.440, ang_vel=0.268, cost=6.214e+03, viol=3.940e-07
# [NMPC] t=108, u_first=[2.350, 3.197], angle=6.451, ang_vel=0.206, cost=6.565e+03, viol=2.630e-07
# [NMPC] t=109, u_first=[2.294, 3.017], angle=6.459, ang_vel=0.153, cost=6.915e+03, viol=1.727e-07
# [NMPC] t=110, u_first=[2.248, 2.865], angle=6.465, ang_vel=0.108, cost=7.263e+03, viol=1.143e-07
# [NMPC] t=111, u_first=[2.209, 2.737], angle=6.470, ang_vel=0.070, cost=7.606e+03, viol=7.680e-08
# [NMPC] t=112, u_first=[2.177, 2.628], angle=6.472, ang_vel=0.037, cost=7.945e+03, viol=5.373e-08
# [NMPC] t=113, u_first=[2.150, 2.536], angle=6.474, ang_vel=0.009, cost=8.279e+03, viol=4.069e-08
# [NMPC] t=114, u_first=[2.129, 2.458], angle=6.474, ang_vel=-0.015, cost=8.606e+03, viol=3.209e-08
# [NMPC] t=115, u_first=[2.112, 2.392], angle=6.473, ang_vel=-0.036, cost=8.926e+03, viol=2.658e-08
# [NMPC] t=116, u_first=[2.099, 2.337], angle=6.472, ang_vel=-0.053, cost=9.240e+03, viol=2.314e-08
# [NMPC] t=117, u_first=[2.089, 2.290], angle=6.470, ang_vel=-0.068, cost=9.546e+03, viol=2.107e-08
# [NMPC] t=118, u_first=[2.082, 2.250], angle=6.467, ang_vel=-0.081, cost=9.844e+03, viol=1.998e-08
# [NMPC] t=119, u_first=[2.077, 2.217], angle=6.464, ang_vel=-0.091, cost=1.013e+04, viol=1.954e-08
# [NMPC] t=120, u_first=[2.075, 2.190], angle=6.460, ang_vel=-0.100, cost=1.042e+04, viol=1.952e-08
# [NMPC] t=121, u_first=[2.074, 2.167], angle=6.456, ang_vel=-0.107, cost=1.069e+04, viol=1.978e-08
# [NMPC] t=122, u_first=[2.075, 2.149], angle=6.452, ang_vel=-0.113, cost=1.096e+04, viol=2.026e-08
# [NMPC] t=123, u_first=[2.077, 2.134], angle=6.447, ang_vel=-0.118, cost=1.121e+04, viol=2.085e-08
# [NMPC] t=124, u_first=[2.080, 2.122], angle=6.443, ang_vel=-0.121, cost=1.146e+04, viol=2.149e-08
# [NMPC] t=125, u_first=[2.084, 2.113], angle=6.438, ang_vel=-0.124, cost=1.170e+04, viol=2.220e-08
# [NMPC] t=126, u_first=[9.135, 2.781], angle=6.433, ang_vel=-0.657, cost=1.164e+04, viol=3.307e-08
# [NMPC] t=127, u_first=[1.194, 0.806], angle=6.407, ang_vel=-0.262, cost=1.170e+04, viol=2.170e-08
# [NMPC] t=128, u_first=[2.151, 1.827], angle=6.396, ang_vel=-0.238, cost=1.182e+04, viol=2.134e-08
# [NMPC] t=129, u_first=[2.182, 1.880], angle=6.387, ang_vel=-0.217, cost=1.195e+04, viol=2.106e-08
# [NMPC] t=130, u_first=[2.192, 1.911], angle=6.378, ang_vel=-0.199, cost=1.207e+04, viol=2.083e-08
# [NMPC] t=131, u_first=[2.201, 1.940], angle=6.370, ang_vel=-0.181, cost=1.219e+04, viol=2.068e-08
# [NMPC] t=132, u_first=[2.208, 1.966], angle=6.363, ang_vel=-0.165, cost=1.230e+04, viol=2.058e-08
# [NMPC] t=133, u_first=[2.214, 1.990], angle=6.356, ang_vel=-0.150, cost=1.242e+04, viol=2.053e-08
# [NMPC] t=134, u_first=[2.219, 2.013], angle=6.350, ang_vel=-0.136, cost=1.253e+04, viol=2.053e-08
# [NMPC] t=135, u_first=[2.223, 2.033], angle=6.345, ang_vel=-0.123, cost=1.263e+04, viol=2.058e-08
# [NMPC] t=136, u_first=[2.227, 2.052], angle=6.340, ang_vel=-0.111, cost=1.274e+04, viol=2.067e-08
# [NMPC] t=137, u_first=[2.229, 2.069], angle=6.335, ang_vel=-0.100, cost=1.284e+04, viol=2.080e-08
# [NMPC] t=138, u_first=[2.232, 2.085], angle=6.331, ang_vel=-0.090, cost=1.294e+04, viol=2.096e-08
# [NMPC] t=139, u_first=[2.233, 2.100], angle=6.328, ang_vel=-0.081, cost=1.303e+04, viol=2.115e-08
# [NMPC] t=140, u_first=[2.235, 2.113], angle=6.325, ang_vel=-0.073, cost=1.313e+04, viol=2.138e-08
# [NMPC] t=141, u_first=[2.235, 2.125], angle=6.322, ang_vel=-0.065, cost=1.322e+04, viol=2.163e-08
# [NMPC] t=142, u_first=[2.236, 2.137], angle=6.319, ang_vel=-0.059, cost=1.331e+04, viol=2.190e-08
# [NMPC] t=143, u_first=[2.236, 2.147], angle=6.317, ang_vel=-0.052, cost=1.340e+04, viol=2.220e-08
# [NMPC] t=144, u_first=[2.237, 2.156], angle=6.315, ang_vel=-0.047, cost=1.349e+04, viol=2.251e-08
# [NMPC] t=145, u_first=[2.237, 2.164], angle=6.313, ang_vel=-0.042, cost=1.357e+04, viol=2.284e-08
# [NMPC] t=146, u_first=[2.236, 2.171], angle=6.311, ang_vel=-0.037, cost=1.365e+04, viol=2.319e-08
# [NMPC] t=147, u_first=[2.236, 2.178], angle=6.310, ang_vel=-0.033, cost=1.374e+04, viol=2.355e-08
# [NMPC] t=148, u_first=[2.236, 2.184], angle=6.308, ang_vel=-0.030, cost=1.381e+04, viol=2.393e-08
# [NMPC] t=149, u_first=[2.235, 2.189], angle=6.307, ang_vel=-0.026, cost=1.389e+04, viol=2.431e-08
# [NMPC] t=150, u_first=[2.234, 2.194], angle=6.306, ang_vel=-0.023, cost=1.397e+04, viol=2.470e-08
# [NMPC] t=151, u_first=[7.010, 0.000], angle=6.305, ang_vel=-0.072, cost=1.478e+04, viol=5.638e-06
# [NMPC] t=152, u_first=[0.000, 0.000], angle=6.302, ang_vel=0.364, cost=1.499e+04, viol=1.157e-07
# [NMPC] t=153, u_first=[1.630, 2.548], angle=6.317, ang_vel=0.364, cost=1.523e+04, viol=3.254e-07
# [NMPC] t=154, u_first=[2.385, 3.460], angle=6.331, ang_vel=0.307, cost=1.545e+04, viol=3.323e-07
# [NMPC] t=155, u_first=[2.454, 3.348], angle=6.344, ang_vel=0.240, cost=1.566e+04, viol=2.174e-07
# [NMPC] t=156, u_first=[2.375, 3.123], angle=6.353, ang_vel=0.185, cost=1.587e+04, viol=1.514e-07
# [NMPC] t=157, u_first=[2.311, 2.939], angle=6.361, ang_vel=0.138, cost=1.607e+04, viol=1.134e-07
# [NMPC] t=158, u_first=[2.260, 2.789], angle=6.366, ang_vel=0.099, cost=1.626e+04, viol=9.144e-08
# [NMPC] t=159, u_first=[2.221, 2.667], angle=6.370, ang_vel=0.066, cost=1.643e+04, viol=7.874e-08
# [NMPC] t=160, u_first=[2.190, 2.567], angle=6.373, ang_vel=0.038, cost=1.659e+04, viol=7.141e-08
# [NMPC] t=161, u_first=[2.166, 2.484], angle=6.374, ang_vel=0.015, cost=1.674e+04, viol=6.725e-08
# [NMPC] t=162, u_first=[2.148, 2.416], angle=6.375, ang_vel=-0.005, cost=1.688e+04, viol=6.489e-08
# [NMPC] t=163, u_first=[2.135, 2.360], angle=6.375, ang_vel=-0.022, cost=1.701e+04, viol=6.356e-08
# [NMPC] t=164, u_first=[2.126, 2.313], angle=6.374, ang_vel=-0.036, cost=1.712e+04, viol=6.280e-08
# [NMPC] t=165, u_first=[2.119, 2.275], angle=6.372, ang_vel=-0.047, cost=1.723e+04, viol=6.235e-08
# [NMPC] t=166, u_first=[2.116, 2.243], angle=6.370, ang_vel=-0.057, cost=1.732e+04, viol=6.214e-08
# [NMPC] t=167, u_first=[2.115, 2.217], angle=6.368, ang_vel=-0.065, cost=1.741e+04, viol=6.193e-08
# [NMPC] t=168, u_first=[2.115, 2.196], angle=6.366, ang_vel=-0.071, cost=1.748e+04, viol=6.168e-08
# [NMPC] t=169, u_first=[2.117, 2.179], angle=6.363, ang_vel=-0.076, cost=1.755e+04, viol=6.136e-08
# [NMPC] t=170, u_first=[2.121, 2.166], angle=6.360, ang_vel=-0.080, cost=1.761e+04, viol=6.103e-08
# [NMPC] t=171, u_first=[2.124, 2.156], angle=6.356, ang_vel=-0.083, cost=1.766e+04, viol=6.064e-08
# [NMPC] t=172, u_first=[2.129, 2.148], angle=6.353, ang_vel=-0.085, cost=1.770e+04, viol=6.024e-08
# [NMPC] t=173, u_first=[2.134, 2.142], angle=6.350, ang_vel=-0.086, cost=1.773e+04, viol=5.980e-08
# [NMPC] t=174, u_first=[2.140, 2.137], angle=6.346, ang_vel=-0.087, cost=1.776e+04, viol=5.932e-08
# [NMPC] t=175, u_first=[2.145, 2.135], angle=6.343, ang_vel=-0.086, cost=1.778e+04, viol=5.878e-08
# [NMPC] t=176, u_first=[6.689, 6.636], angle=6.339, ang_vel=-0.501, cost=1.748e+04, viol=1.514e-07
# [NMPC] t=177, u_first=[2.585, 1.650], angle=6.319, ang_vel=-0.498, cost=1.718e+04, viol=8.402e-08
# [NMPC] t=178, u_first=[2.583, 1.700], angle=6.299, ang_vel=-0.440, cost=1.691e+04, viol=6.976e-08
# [NMPC] t=179, u_first=[2.575, 1.750], angle=6.282, ang_vel=-0.385, cost=1.666e+04, viol=5.853e-08
# [NMPC] t=180, u_first=[2.561, 1.795], angle=6.266, ang_vel=-0.334, cost=1.641e+04, viol=4.977e-08
# [NMPC] t=181, u_first=[2.542, 1.835], angle=6.253, ang_vel=-0.286, cost=1.618e+04, viol=4.293e-08
# [NMPC] t=182, u_first=[2.521, 1.871], angle=6.242, ang_vel=-0.242, cost=1.597e+04, viol=3.760e-08
# [NMPC] t=183, u_first=[2.498, 1.904], angle=6.232, ang_vel=-0.201, cost=1.576e+04, viol=3.343e-08
# [NMPC] t=184, u_first=[2.475, 1.935], angle=6.224, ang_vel=-0.165, cost=1.557e+04, viol=3.015e-08
# [NMPC] t=185, u_first=[2.453, 1.964], angle=6.217, ang_vel=-0.131, cost=1.540e+04, viol=2.756e-08
# [NMPC] t=186, u_first=[2.431, 1.991], angle=6.212, ang_vel=-0.100, cost=1.524e+04, viol=2.552e-08
# [NMPC] t=187, u_first=[2.411, 2.016], angle=6.208, ang_vel=-0.073, cost=1.509e+04, viol=2.394e-08
# [NMPC] t=188, u_first=[2.392, 2.041], angle=6.205, ang_vel=-0.049, cost=1.495e+04, viol=2.270e-08
# [NMPC] t=189, u_first=[2.374, 2.064], angle=6.203, ang_vel=-0.027, cost=1.482e+04, viol=2.173e-08
# [NMPC] t=190, u_first=[2.359, 2.086], angle=6.202, ang_vel=-0.007, cost=1.471e+04, viol=2.100e-08
# [NMPC] t=191, u_first=[2.344, 2.106], angle=6.202, ang_vel=0.010, cost=1.461e+04, viol=2.045e-08
# [NMPC] t=192, u_first=[2.331, 2.126], angle=6.202, ang_vel=0.024, cost=1.452e+04, viol=2.005e-08
# [NMPC] t=193, u_first=[2.320, 2.144], angle=6.203, ang_vel=0.037, cost=1.444e+04, viol=1.979e-08
# [NMPC] t=194, u_first=[2.309, 2.161], angle=6.205, ang_vel=0.048, cost=1.438e+04, viol=1.966e-08
# [NMPC] t=195, u_first=[2.300, 2.177], angle=6.207, ang_vel=0.057, cost=1.432e+04, viol=1.964e-08
# [NMPC] t=196, u_first=[2.292, 2.191], angle=6.209, ang_vel=0.065, cost=1.427e+04, viol=1.969e-08
# [NMPC] t=197, u_first=[2.284, 2.205], angle=6.212, ang_vel=0.071, cost=1.423e+04, viol=1.982e-08
# [NMPC] t=198, u_first=[2.278, 2.217], angle=6.214, ang_vel=0.076, cost=1.420e+04, viol=2.002e-08
# [NMPC] t=199, u_first=[2.272, 2.227], angle=6.217, ang_vel=0.080, cost=1.418e+04, viol=2.028e-08
# [NMPC] t=200, u_first=[2.266, 2.237], angle=6.221, ang_vel=0.083, cost=1.416e+04, viol=2.058e-08
# [NMPC] t=201, u_first=[0.000, 10.000], angle=6.224, ang_vel=0.731, cost=1.439e+04, viol=2.683e-06
# [NMPC] t=202, u_first=[0.000, 9.287], angle=6.253, ang_vel=0.108, cost=1.413e+04, viol=4.185e-07
# [NMPC] t=203, u_first=[0.000, 0.000], angle=6.257, ang_vel=-0.469, cost=1.389e+04, viol=1.223e-07
# [NMPC] t=204, u_first=[0.183, 0.491], angle=6.239, ang_vel=-0.469, cost=1.358e+04, viol=1.394e-07
# [NMPC] t=205, u_first=[2.908, 1.509], angle=6.220, ang_vel=-0.489, cost=1.328e+04, viol=3.102e-08
# [NMPC] t=206, u_first=[3.190, 1.924], angle=6.200, ang_vel=-0.402, cost=1.297e+04, viol=2.459e-08
# [NMPC] t=207, u_first=[3.057, 1.932], angle=6.184, ang_vel=-0.323, cost=1.269e+04, viol=1.967e-08
# [NMPC] t=208, u_first=[2.929, 1.933], angle=6.171, ang_vel=-0.253, cost=1.244e+04, viol=1.599e-08
# [NMPC] t=209, u_first=[2.816, 1.937], angle=6.161, ang_vel=-0.191, cost=1.221e+04, viol=1.329e-08
# [NMPC] t=210, u_first=[2.718, 1.945], angle=6.154, ang_vel=-0.136, cost=1.201e+04, viol=1.134e-08
# [NMPC] t=211, u_first=[2.633, 1.955], angle=6.148, ang_vel=-0.088, cost=1.183e+04, viol=9.944e-09
# [NMPC] t=212, u_first=[2.560, 1.969], angle=6.145, ang_vel=-0.046, cost=1.167e+04, viol=8.951e-09
# [NMPC] t=213, u_first=[2.499, 1.985], angle=6.143, ang_vel=-0.009, cost=1.154e+04, viol=8.255e-09
# [NMPC] t=214, u_first=[2.447, 2.004], angle=6.143, ang_vel=0.023, cost=1.142e+04, viol=7.772e-09
# [NMPC] t=215, u_first=[2.404, 2.024], angle=6.143, ang_vel=0.051, cost=1.133e+04, viol=7.465e-09
# [NMPC] t=216, u_first=[2.368, 2.046], angle=6.145, ang_vel=0.074, cost=1.125e+04, viol=7.288e-09
# [NMPC] t=217, u_first=[2.339, 2.069], angle=6.148, ang_vel=0.094, cost=1.119e+04, viol=7.210e-09
# [NMPC] t=218, u_first=[2.315, 2.092], angle=6.152, ang_vel=0.111, cost=1.114e+04, viol=7.218e-09
# [NMPC] t=219, u_first=[2.295, 2.115], angle=6.157, ang_vel=0.125, cost=1.111e+04, viol=7.305e-09
# [NMPC] t=220, u_first=[2.279, 2.138], angle=6.162, ang_vel=0.136, cost=1.109e+04, viol=7.460e-09
# [NMPC] t=221, u_first=[2.267, 2.160], angle=6.167, ang_vel=0.145, cost=1.109e+04, viol=7.672e-09
# [NMPC] t=222, u_first=[2.256, 2.181], angle=6.173, ang_vel=0.152, cost=1.110e+04, viol=7.938e-09
# [NMPC] t=223, u_first=[2.248, 2.201], angle=6.179, ang_vel=0.156, cost=1.112e+04, viol=8.263e-09
# [NMPC] t=224, u_first=[2.242, 2.219], angle=6.185, ang_vel=0.159, cost=1.115e+04, viol=8.649e-09
# [NMPC] t=225, u_first=[2.236, 2.236], angle=6.192, ang_vel=0.161, cost=1.120e+04, viol=9.082e-09
# Solver NONE BREAKING
# [NMPC] t=226, u_first=[2.149, 2.678], angle=6.198, ang_vel=-0.481, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=227, u_first=[2.164, 2.468], angle=6.179, ang_vel=-0.514, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=228, u_first=[2.211, 2.331], angle=6.158, ang_vel=-0.532, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=229, u_first=[2.279, 2.244], angle=6.137, ang_vel=-0.540, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=230, u_first=[2.357, 2.189], angle=6.115, ang_vel=-0.538, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=231, u_first=[2.436, 2.155], angle=6.094, ang_vel=-0.527, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=232, u_first=[2.505, 2.130], angle=6.073, ang_vel=-0.510, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=233, u_first=[2.554, 2.109], angle=6.052, ang_vel=-0.487, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=234, u_first=[2.573, 2.084], angle=6.033, ang_vel=-0.459, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=235, u_first=[2.555, 2.050], angle=6.015, ang_vel=-0.428, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=236, u_first=[2.493, 2.001], angle=5.997, ang_vel=-0.397, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=237, u_first=[2.386, 1.934], angle=5.982, ang_vel=-0.366, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=238, u_first=[2.236, 1.845], angle=5.967, ang_vel=-0.338, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=239, u_first=[2.046, 1.733], angle=5.953, ang_vel=-0.314, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=240, u_first=[2.020, 1.382], angle=5.941, ang_vel=-0.295, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=241, u_first=[2.020, 1.382], angle=5.929, ang_vel=-0.255, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=242, u_first=[2.020, 1.382], angle=5.919, ang_vel=-0.215, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=243, u_first=[2.020, 1.382], angle=5.910, ang_vel=-0.175, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=244, u_first=[2.020, 1.382], angle=5.903, ang_vel=-0.136, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=245, u_first=[2.020, 1.382], angle=5.898, ang_vel=-0.096, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=246, u_first=[2.020, 1.382], angle=5.894, ang_vel=-0.056, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=247, u_first=[2.020, 1.382], angle=5.892, ang_vel=-0.017, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=248, u_first=[2.020, 1.382], angle=5.891, ang_vel=0.023, cost=inf, viol=inf
# Solver NONE BREAKING
# [NMPC] t=249, u_first=[2.020, 1.382], angle=5.892, ang_vel=0.063, cost=inf, viol=inf
# Simulation done in 53.04 s
# <video width="850" height="850" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# ---------------------------
# PART 2: SQP/KKT NMPC (single-cell)
# Assumes Part-1 already ran and produced x_sol (xdim x (N+1)) and u_sol (udim x N)
# ---------------------------

import time
import numpy as np
from qpsolvers import solve_qp
import quadrotor
from quadrotor import next_state

# ----- NMPC parameters -----
N_mpc = 30                 # horizon used in NMPC (user requested 60)
sqp_iters_per_step = 3     # small number of SQP iterations each control step
R_stage = 0.1          # stage control weight (user requested small R)
eps_reg = 1e-6             # regularization for QP Hessian
u_min = np.array([0.0, 0.0])
u_max = np.array([10.0, 10.0])
du_max = np.array([1.0, 1.0])   # simple rate limit per timestep (tunable)
print_freq = 1

# state/control dims (consistent with Part-1/quadrotor)
xdim = quadrotor.DIM_STATE
udim = quadrotor.DIM_CONTROL

# make sure references exist
try:
    x_ref_full = x_sol.copy()
    u_ref_full = u_sol.copy()
except NameError:
    raise RuntimeError("Part-1 reference (x_sol, u_sol) not found. Run Part-1 cell first.")

# helper to pack/unpack decision vector Z = [x0,u0, x1,u1, ..., xN]
def pack_Z(x_traj, u_traj):
    # x_traj: (xdim, Nloc+1), u_traj: (udim, Nloc)
    Nloc = u_traj.shape[1]
    nvars = (Nloc * udim) + ((Nloc + 1) * xdim)
    Z = np.zeros(nvars)
    for n in range(Nloc):
        idx_x = n * (xdim + udim)
        idx_u = idx_x + xdim
        Z[idx_x: idx_x + xdim] = x_traj[:, n]
        Z[idx_u: idx_u + udim] = u_traj[:, n]
    idx_xN = Nloc * (xdim + udim)
    Z[idx_xN: idx_xN + xdim] = x_traj[:, Nloc]
    return Z

def unpack_Z(Z, Nloc):
    x = np.zeros((xdim, Nloc + 1))
    u = np.zeros((udim, Nloc))
    for n in range(Nloc):
        idx_x = n * (xdim + udim)
        idx_u = idx_x + xdim
        x[:, n] = Z[idx_x: idx_x + xdim]
        u[:, n] = Z[idx_u: idx_u + udim]
    idx_xN = Nloc * (xdim + udim)
    x[:, Nloc] = Z[idx_xN: idx_xN + xdim]
    return x, u

# cost Hessian construction for local horizon
def build_local_G(Q_stage, R_stage_local, Qf_stage, Nloc):
    nvars = (Nloc * udim) + ((Nloc + 1) * xdim)
    G = np.zeros((nvars, nvars))
    for i in range(Nloc):
        idx_x = i * (xdim + udim)
        G[idx_x: idx_x + xdim, idx_x: idx_x + xdim] = Q_stage
        idx_u = idx_x + xdim
        G[idx_u: idx_u + udim, idx_u: idx_u + udim] = R_stage_local
    idx_xN = Nloc * (xdim + udim)
    G[idx_xN: idx_xN + xdim, idx_xN: idx_xN + xdim] = Qf_stage
    return G

# gradient (linear term) for tracking (q in 0.5 z'Pz + q'z)
def build_local_q(x_traj, u_traj, x_ref_loc, u_ref_loc, Q_stage, R_stage_local, Qf_stage):
    Nloc = u_traj.shape[1]
    nvars = (Nloc * udim) + ((Nloc + 1) * xdim)
    q = np.zeros(nvars)
    for n in range(Nloc):
        idx_x = n * (xdim + udim)
        idx_u = idx_x + xdim
        # note: q is gradient -> for standard quadratic 1/2*z'Pz + q'z where q = linear term
        # Here we use q = -P * z_ref (so that minimizing pulls to z_ref). Simpler: use difference around current Z
        q[idx_x: idx_x + xdim] = - Q_stage @ x_ref_loc[:, n]
        q[idx_u: idx_u + udim] = - R_stage_local @ u_ref_loc[:, n]
    idx_xN = Nloc * (xdim + udim)
    q[idx_xN: idx_xN + xdim] = - Qf_stage @ x_ref_loc[:, Nloc]
    return q

# dynamics linearization A/B (Euler discrete-time linearization as in Part-1)
def calc_A(x_n, u_n):
    # Keep same calc_A as in Part-1 to ensure consistent linearization
    px = x_n[0]; vx = x_n[1]; py = x_n[2]; vy = x_n[3]; theta = x_n[4]; w = x_n[5]
    u1 = u_n[0]; u2 = u_n[1]
    grad_dx = np.zeros((xdim, xdim))
    grad_dx[0,1] = 1.0
    grad_dx[1,4] = -(u1 + u2)*(np.cos(theta))/quadrotor.MASS
    grad_dx[2,3] = 1.0
    grad_dx[3,4] = -(u1 + u2)*(np.sin(theta))/quadrotor.MASS
    grad_dx[4,5] = 1.0
    grad_dx[5,:]  = [0,0,0,0,0,0]
    A_n = np.eye(xdim) + (quadrotor.DT)*(grad_dx)
    return A_n

def calc_B(x_n, u_n):
    theta = x_n[4]
    grad_du = np.zeros((xdim, udim))
    grad_du[0,:] = [0,0]
    grad_du[1,0] = -(np.sin(theta))/quadrotor.MASS
    grad_du[1,1] = -(np.sin(theta))/quadrotor.MASS
    grad_du[2,:] = [0,0]
    grad_du[3,0] = np.cos(theta)/quadrotor.MASS
    grad_du[3,1] = np.cos(theta)/quadrotor.MASS
    grad_du[4,:] = [0,0]
    grad_du[5,0] = quadrotor.LENGTH/quadrotor.INERTIA
    grad_du[5,1] = -(quadrotor.LENGTH)/quadrotor.INERTIA
    B_n = quadrotor.DT * grad_du
    return B_n

# build linear equality constraints M_loc Z = p_loc (dyn linearization)
def build_M_p_from_Z(Z_guess, x0, Nloc):
    n_constr = (Nloc + 1) * xdim
    nvars = Z_guess.size
    M = np.zeros((n_constr, nvars))
    p = np.zeros(n_constr)
    x_mat, u_mat = unpack_Z(Z_guess, Nloc)
    # initial condition
    M[0:xdim, 0:xdim] = np.eye(xdim)
    p[0:xdim] = x0
    # dynamics rows
    for n in range(Nloc):
        x_n = x_mat[:, n].copy()
        u_n = u_mat[:, n].copy()
        x_np1 = x_mat[:, n+1].copy()
        x_np1_pred = next_state(x_n, u_n)
        A_n = calc_A(x_n, u_n)
        B_n = calc_B(x_n, u_n)
        row_s = (n+1)*xdim
        row_e = (n+2)*xdim
        col_xn = n*(xdim + udim)
        col_un = col_xn + xdim
        col_xnp1 = (n+1)*(xdim + udim)
        M[row_s:row_e, col_xn:col_xn+xdim] = A_n
        M[row_s:row_e, col_un:col_un+udim] = B_n
        M[row_s:row_e, col_xnp1:col_xnp1+xdim] = -np.eye(xdim)
        p[row_s:row_e] = x_np1 - x_np1_pred
    return M, p

# inequality constraints H z <= h (control box + ground height constraint)
def build_H_h_from_Z(Z_guess, Nloc, epsilon_ground=1e-3):
    n_ineq = 4 * Nloc + (Nloc + 1)   # 4 control bounds per stage + ground height constraint per state
    H = np.zeros((n_ineq, Z_guess.size))
    h = np.zeros(n_ineq)
    row = 0
    x_mat, u_mat = unpack_Z(Z_guess, Nloc)
    for n in range(Nloc):
        idx_u1 = n*(xdim + udim) + xdim
        idx_u2 = idx_u1 + 1
        # u <= umax
        H[row, idx_u1] = 1.0; h[row] = u_max[0]; row += 1
        H[row, idx_u2] = 1.0; h[row] = u_max[1]; row += 1
        # -u <= -umin  -> u >= umin
        H[row, idx_u1] = -1.0; h[row] = -u_min[0]; row += 1
        H[row, idx_u2] = -1.0; h[row] = -u_min[1]; row += 1
    # ground height constraint: y >= 0 => -y <= -epsilon (we'll use a small epsilon)
    for n in range(Nloc + 1):
        idx_xn_2 = n*(xdim + udim) + 2
        H[row, idx_xn_2] = -1.0
        h[row] = -epsilon_ground
        row += 1
    return H, h

# ----- Global warm-start memory (persist across controller calls) -----
_prev_Zwarm = None
_prev_u_applied = None

# Create a smoother warm-start generator: take slice from reference and pad if needed
def make_initial_Z_warm(x0, t_idx, Nloc):
    # pick reference start index aligned with current time t_idx (t_idx is integer step)
    # prefer to use x_ref_full/u_ref_full if long enough; otherwise use last available and repeat last control
    total_ref_len = x_ref_full.shape[1]
    ref_start = min(t_idx, total_ref_len - 1)
    ref_end = ref_start + Nloc
    if ref_end <= total_ref_len - 1:
        x_ref_loc = x_ref_full[:, ref_start: ref_start + Nloc + 1].copy()
        u_ref_loc = u_ref_full[:, ref_start: ref_start + Nloc].copy()
    else:
        # slice available part, then pad with hover
        avail = max(0, total_ref_len - 1 - ref_start)
        x_ref_loc = np.zeros((xdim, Nloc + 1))
        u_ref_loc = np.zeros((udim, Nloc))
        if avail > 0:
            x_ref_loc[:, :avail+1] = x_ref_full[:, ref_start: ref_start + avail + 1]
            u_ref_loc[:, :avail]  = u_ref_full[:, ref_start: ref_start + avail]
        # pad rest with last reference or hover
        last_x = x_ref_full[:, -1].copy()
        last_u = u_ref_full[:, -1].copy()
        for k in range(avail+1, Nloc+1):
            x_ref_loc[:, k] = last_x
        for k in range(avail, Nloc):
            u_ref_loc[:, k] = last_u
    # pack
    return pack_Z(x_ref_loc, u_ref_loc), x_ref_loc, u_ref_loc

# main NMPC controller factory
def make_sqp_kkt_nmpc():
    global _prev_Zwarm, _prev_u_applied

    def controller(x_current, t_idx):
        # declare globals at very top of controller (fixes earlier global usage bug)
        global _prev_Zwarm, _prev_u_applied

        # SHORT HORIZON ADJUSTMENT: if too close to end of reference, shrink horizon
        remaining_ref = x_ref_full.shape[1] - t_idx
        Nloc = min(N_mpc, max(5, remaining_ref - 1))  # at least 5 steps
        if Nloc <= 0:
            # fallback hover
            u_hover = np.array([quadrotor.MASS*quadrotor.GRAVITY_CONSTANT/2.0,
                                quadrotor.MASS*quadrotor.GRAVITY_CONSTANT/2.0])
            return u_hover

        # build warm-start Z
        if (_prev_Zwarm is None) or (_prev_Zwarm.size != ((Nloc * udim) + ((Nloc + 1) * xdim))):
            Z_warm, x_ref_loc, u_ref_loc = make_initial_Z_warm(x_current, t_idx, Nloc)
        else:
            # shift previous warm by one stage and append last ref
            old_x, old_u = unpack_Z(_prev_Zwarm, prev_Nloc := ( _prev_Zwarm.size - xdim)//(xdim + udim) )
            # if prev_Nloc != Nloc we regenerate
            if prev_Nloc == Nloc:
                x_shift = np.zeros((xdim, Nloc+1))
                u_shift = np.zeros((udim, Nloc))
                # shift: new x0 = current measured state
                x_shift[:, 0] = x_current
                for k in range(0, Nloc):
                    if k < Nloc - 1:
                        x_shift[:, k+1] = old_x[:, k+1]
                    else:
                        # last state: repeat last
                        x_shift[:, k+1] = old_x[:, -1]
                for k in range(0, Nloc):
                    if k < Nloc - 1:
                        u_shift[:, k] = old_u[:, k+1]
                    else:
                        u_shift[:, k] = old_u[:, -1]
                Z_warm = pack_Z(x_shift, u_shift)
            else:
                Z_warm, x_ref_loc, u_ref_loc = make_initial_Z_warm(x_current, t_idx, Nloc)

        # ensure dimensions
        nvars = Z_warm.size

        # cost weights (tracking around reference)
        Q_stage = np.diag([50.0, 2.0, 500.0, 5.0, 800.0, 50.0])   # stronger state tracking
        Qf_stage = np.diag([500.0, 5.0, 2000.0, 10.0, 2500.0, 200.0])
        R_stage_local = np.eye(udim) * R_stage

        # Prepare quadratic cost (Hessian) and linear term q
        # We'll construct q to track the reference embedded in Z_warm (or from reference slices)
        # Extract reference slice for linear term:
        # if we have x_ref_full available for this t_idx, use it, otherwise derive from Z_warm
        total_ref_len = x_ref_full.shape[1]
        if t_idx + Nloc <= total_ref_len - 1:
            x_ref_loc = x_ref_full[:, t_idx: t_idx + Nloc + 1]
            u_ref_loc = u_ref_full[:, t_idx: t_idx + Nloc]
        else:
            # use warm's own states as reference
            x_ref_loc, u_ref_loc = unpack_Z(Z_warm, Nloc)

        G_local = build_local_G(Q_stage, R_stage_local, Qf_stage, Nloc)
        # regularize Hessian
        G_local += eps_reg * np.eye(G_local.shape[0])
        q_local = build_local_q(*unpack_Z(Z_warm, Nloc), x_ref_loc, u_ref_loc, Q_stage, R_stage_local, Qf_stage)

        # SQP inner iterations: linearize dynamics around current Z_guess (start from Z_warm)
        Z_guess = Z_warm.copy()
        for sqp_it in range(sqp_iters_per_step):
            # build linearized equality constraints
            M_loc, p_loc = build_M_p_from_Z(Z_guess, x_current, Nloc)
            # inequalities
            H_loc, h_loc = build_H_h_from_Z(Z_guess, Nloc)
            try:
                # Solve QP: min 0.5 z'G z + q'z s.t. H z <= h, M z = p
                dZ = solve_qp(G_local, q_local, H_loc, h_loc, M_loc, p_loc, solver='cvxopt')
                if dZ is None:
                    # QP failed; break and fallback
                    break
                # interpret solve_qp output as Z solution (not step); we use full step to new Z
                Z_guess = dZ.copy()
            except Exception as e:
                # QP solver error -> break and fallback
                # print("QP fail:", e)
                break

        # store warm for next timestep
        _prev_Zwarm = Z_guess.copy()

        # extract first control from optimized Z_guess
        x_opt, u_opt = unpack_Z(Z_guess, Nloc)
        u_first = u_opt[:, 0].copy()

        # clip to bounds
        u_first = np.clip(u_first, u_min, u_max)

        # apply rate limit relative to last applied
        if _prev_u_applied is None:
            _prev_u_applied = u_first.copy()
        u_first = np.clip(u_first, _prev_u_applied - du_max, _prev_u_applied + du_max)
        _prev_u_applied = u_first.copy()

        # Diagnostics (limited printing)
        if (t_idx % print_freq) == 0:
            # evaluate simple cost/viol for diagnostics
            try:
                x_eval, u_eval = unpack_Z(Z_guess, Nloc)
                cost_eval = 0.0
                viol_eval = 0.0
                for k in range(Nloc):
                    dx = (x_eval[:, k] - x_ref_loc[:, k])
                    cost_eval += 0.5 * (dx @ Q_stage @ dx) + 0.5 * (u_eval[:, k] @ R_stage_local @ u_eval[:, k])
                    # predicted dynamics residual
                    x_pred = next_state(x_eval[:, k], u_eval[:, k])
                    viol_eval += np.sum(np.abs(x_pred - x_eval[:, k+1]))
                # terminal
                dxN = x_eval[:, -1] - x_ref_loc[:, -1]
                cost_eval += 0.5 * (dxN @ Qf_stage @ dxN)
            except Exception:
                cost_eval = np.nan; viol_eval = np.nan

            angle = float(x_current[4])
            ang_vel = float(x_current[5])
            # print compact line
            print(f"[NMPC] t={t_idx:03d}, u_first=[{u_first[0]:.3f}, {u_first[1]:.3f}], angle={angle:+.3f}, ang_vel={ang_vel:+.3f}, cost={cost_eval:.3e}, viol={viol_eval:.3e}")

        return u_first

    return controller

# create controller and simulate
mpc_ctrl = make_sqp_kkt_nmpc()

print("\n" + "="*60)
print("Running SQP/KKT NMPC closed-loop (disturbance=True)...")
print("="*60)
t0 = time.time()
x0 = x_ref_full[:, 0].copy()  # start at Part-1 initial reference
sim_steps = min(250, x_ref_full.shape[1]-1)  # simulate up to ref length or 250 steps

# run simulation (quadrotor.simulate expects (state, controller, horizon_length, disturbance=True))
t_mpc, state_mpc, u_mpc = quadrotor.simulate(x0, mpc_ctrl, sim_steps, True)
print(f"Simulation done in {time.time()-t0:.2f} s")

# compute simple tracking metrics on overlap portion
overlap = min(state_mpc.shape[1], x_ref_full.shape[1])
tracking_norms = np.linalg.norm(state_mpc[:, :overlap] - x_ref_full[:, :overlap], axis=0)
print(f"Final tracking norm (overlap): {np.linalg.norm(tracking_norms):.4f}")
print(f"Tracking norm @ t={4.0:.2f}s : norm = {np.linalg.norm(tracking_norms[int(4.0/quadrotor.DT)]):.4f}" if (int(4.0/quadrotor.DT) < overlap) else "")
print(f"Height min/max: {np.min(state_mpc[2, :]):.3f} {np.max(state_mpc[2, :]):.3f}")

# optionally animate (uncomment if desired)
# quadrotor.animate_robot(state_mpc, u_mpc)

# plotting (compact)
import matplotlib.pyplot as plt
time_states_mpc = np.arange(state_mpc.shape[1]) * quadrotor.DT
time_ref = np.arange(x_ref_full.shape[1]) * quadrotor.DT

plt.figure(figsize=(12,8))
state_labels = ['x-pos (m)', 'x-vel (m/s)', 'y-pos (m)', 'y-vel (m/s)', 'Angle (rad)', 'Ang vel (rad/s)']
for i in range(xdim):
    plt.subplot(3, 2, i+1)
    plt.plot(time_states_mpc, state_mpc[i, :], label='MPC')
    plt.plot(time_ref, x_ref_full[i, :], '--', label='Ref', alpha=0.6)
    plt.ylabel(state_labels[i]); plt.xlabel('Time (s)'); plt.grid(True); plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,6))
plt.plot(state_mpc[0, :], state_mpc[2, :], label='MPC actual')
plt.plot(x_ref_full[0, :], x_ref_full[2, :], '--', label='Reference', alpha=0.6)
plt.title('Trajectory (x vs y)')
plt.legend(); plt.grid(True); plt.axis('equal')
plt.show()

# %%
# -----------------------------
# Part-2: NMPC controller cell
# Drop-in replacement for your current controller cell
# -----------------------------

import numpy as np
from qpsolvers import solve_qp
import time

# -----------------------------
# PARAMETERS (adjust if needed)
# -----------------------------
# local MPC horizon (number of stages)
N_mpc = 35                # set smaller for faster loops; you can change to 20/30/60
stage_len = 8             # your Z stage size (6 states + 2 controls)
Zlen = N_mpc * stage_len

# QP inner iterations per control call (SQP inner loops)
max_inner_iters = 5

# actuator bounds
U_MIN = 0.0
U_MAX = 10.0

# -----------------------------
# Build / reuse cost matrix (expects your make_Cost_Matrix function)
# -----------------------------
try:
    Ca_mpc = make_Cost_Matrix(N_mpc)   # keep same weighting architecture as your part-1
except Exception as e:
    print("[NMPC] make_Cost_Matrix failed — make sure it is defined:", e)
    Ca_mpc = np.eye(Zlen) * 1e-3

# -----------------------------
# Global warm-start buffer (persist between controller calls)
# -----------------------------
# we use a module-global variable named Z_warm (safe global, avoids nonlocal)
if 'Z_warm' not in globals() or (isinstance(globals().get('Z_warm'), np.ndarray) and globals().get('Z_warm').size != Zlen):
    # Try to initialize from x_ref_full if available, otherwise from tiled default
    if 'x_ref_full' in globals() and isinstance(x_ref_full, np.ndarray) and x_ref_full.size > 0:
        # if x_ref_full has shape (6, T) and u_ref_full (2, T-1) produce Z sequence of length N_mpc
        try:
            # create initial Z_warm from first N_mpc steps of x_ref_full and u_ref_full
            T_full = x_ref_full.shape[1]
            # If not enough steps, tile last column
            def build_initial_Z_from_ref(start_idx=0):
                Z0 = np.zeros(Zlen)
                for n in range(N_mpc):
                    t_idx = min(start_idx + n, T_full - 1)
                    base = n * stage_len
                    # states
                    Z0[base:base + 6] = x_ref_full[:, t_idx]
                    # controls: use u_ref_full at t_idx if exists else last column or hover
                    if 'u_ref_full' in globals() and isinstance(u_ref_full, np.ndarray) and u_ref_full.shape[1] > 0:
                        ctrl_idx = min(start_idx + n, u_ref_full.shape[1] - 1)
                        Z0[base + 6: base + 8] = u_ref_full[:, ctrl_idx]
                    else:
                        hover = (quadrotor.MASS * quadrotor.GRAVITY_CONSTANT) / 2.0 if hasattr(quadrotor, 'MASS') else 5.0
                        Z0[base + 6: base + 8] = np.array([hover, hover])
                return Z0
            Z_warm = build_initial_Z_from_ref(0)
        except Exception:
            Z_warm = np.zeros(Zlen)
    else:
        # fallback tiled reference (like original)
        hover_guess = (quadrotor.MASS * quadrotor.GRAVITY_CONSTANT) / 2.0 if hasattr(quadrotor, 'MASS') else 5.0
        base_stage = np.array([0.0, 0.0, 2.0, 0.0, 2*np.pi, 0.0, hover_guess, hover_guess])
        Z_warm = np.tile(base_stage, N_mpc)

# -----------------------------
# Helper: slice the right reference window from full reference arrays
# -----------------------------
def build_ref_window(t_idx):
    # Prefer user-provided x_ref_full/u_ref_full
    if 'x_ref_full' in globals() and isinstance(x_ref_full, np.ndarray) and x_ref_full.shape[1] > 0:
        T = x_ref_full.shape[1]
        Xd_win = np.zeros(Zlen)
        for n in range(N_mpc):
            t_ref = min(t_idx + n, T - 1)
            base = n * stage_len
            Xd_win[base: base + 6] = x_ref_full[:, t_ref]
            if 'u_ref_full' in globals() and isinstance(u_ref_full, np.ndarray) and u_ref_full.shape[1] > 0:
                u_t = min(t_idx + n, u_ref_full.shape[1] - 1)
                Xd_win[base + 6: base + 8] = u_ref_full[:, u_t]
            else:
                hover = (quadrotor.MASS * quadrotor.GRAVITY_CONSTANT) / 2.0 if hasattr(quadrotor, 'MASS') else 5.0
                Xd_win[base + 6: base + 8] = np.array([hover, hover])
        return Xd_win
    else:
        hover = (quadrotor.MASS * quadrotor.GRAVITY_CONSTANT) / 2.0 if hasattr(quadrotor, 'MASS') else 5.0
        base_stage = np.array([0.0, 0.0, 2.0, 0.0, 2*np.pi, 0.0, hover, hover])
        return np.tile(base_stage, N_mpc)

# -----------------------------
# Controller function (drop-in for quadrotor.simulate)
# -----------------------------
def nmpc_controller(x, t_idx):
    
    global Z_warm, Ca_mpc

    # ensure shapes
    x = np.asarray(x).flatten()
    if x.size < 6:
        x = np.concatenate([x, np.zeros(6 - x.size)])

    Xd_win = build_ref_window(t_idx)

    Z_warm = np.roll(Z_warm, -stage_len)  # shift left by one stage
    Z_warm[-stage_len:] = Xd_win[-stage_len:]  # last stage <- last ref stage

    # Overwrite first stage's state with current measured state to enforce initial condition
    Z_warm[0:6] = x
    # keep first-stage control from warm-start but clip
    Z_warm[6:8] = np.clip(Z_warm[6:8], U_MIN, U_MAX)

    # filter-line-search bookkeeping
    f_best = float('inf')
    c_best = float('inf')

    # inner SQP iterations (each solves a QP and performs a line-search)
    for it in range(max_inner_iters):
        # build linearized constraints around Z_warm
        try:
            xt, A, b, G, h = get_Constraints(Z_warm)   # must match your implementation
        except Exception as e:
            print(f"[NMPC] get_Constraints failed at t={t_idx}, it={it}: {e}")
            break

        # Quadratic cost: P, linear term q
        P = Ca_mpc
        q = P @ (Z_warm - Xd_win)

        try:
            delta_Z = solve_qp(P=P, q=q, A=A, b=b, G=G, h=h, solver='cvxopt')
        except Exception as e:
            print(f"[NMPC] QP solver exception at t={t_idx}, it={it}: {e}")
            delta_Z = None

        if delta_Z is None:
            # solver failed — leave warm-start as-is and exit inner loop
            print(f"[NMPC] QP returned None at t={t_idx}, it={it}. Using warm-start control.")
            break

        try:
            alpha, uc, gammas = line_search(Z_warm, delta_Z, Xd_win, Ca_mpc, f_best, c_best, alpha=1)
        except TypeError:
            try:
                # try signature with fewer args
                alpha, uc, gammas = line_search(Z_warm, delta_Z, f_best, c_best)
            except TypeError:
                try:
                    alpha, uc, gammas = line_search(Z_warm, delta_Z)
                except Exception as e:
                    print(f"[NMPC] line_search call failed at t={t_idx}, it={it}: {e}")
                    alpha = 0.0
        except Exception as e:
            print(f"[NMPC] line_search threw exception at t={t_idx}, it={it}: {e}")
            alpha = 0.0

        if alpha is None:
            alpha = 0.0

        # Accept step
        Z_warm = Z_warm + alpha * delta_Z

        if alpha < 1e-6 or np.linalg.norm(delta_Z) < 1e-6:
            break

    # extract first control from warm-start (staged layout)
    u0 = Z_warm[6:8].astype(float)
    u0 = np.clip(u0, U_MIN, U_MAX)

    # Debug summary print (safe formatting)
    theta = float(x[4]) if x.size > 4 else 0.0
    w = float(x[5]) if x.size > 5 else 0.0
    print(f"[NMPC] t={t_idx:03d}, u_first=[{u0[0]:.3f}, {u0[1]:.3f}], angle={theta:+.3f}, ang_vel={w:+.3f}")

    return u0


x0 = np.zeros(6)
horizon_length = 250  
t_mpc, state_mpc, u_mpc = quadrotor.simulate(x0, nmpc_controller, horizon_length, disturbance=True)

print("NMPC simulation finished.")
print("Final height:", state_mpc[2, -1])
print("Min height:", np.min(state_mpc[2, :]), "Max height:", np.max(state_mpc[2, :]))

quadrotor.animate_robot(state_mpc, u_mpc)
# Out:
# [NMPC] make_Cost_Matrix failed — make sure it is defined: name 'make_Cost_Matrix' is not defined
# [NMPC] get_Constraints failed at t=0, it=0: name 'get_Constraints' is not defined
# [NMPC] t=000, u_first=[2.149, 2.267], angle=+0.000, ang_vel=+0.000
# [NMPC] get_Constraints failed at t=1, it=0: name 'get_Constraints' is not defined
# [NMPC] t=001, u_first=[2.140, 2.277], angle=+0.000, ang_vel=+0.283
# [NMPC] get_Constraints failed at t=2, it=0: name 'get_Constraints' is not defined
# [NMPC] t=002, u_first=[2.136, 2.280], angle=+0.011, ang_vel=+0.275
# [NMPC] get_Constraints failed at t=3, it=0: name 'get_Constraints' is not defined
# [NMPC] t=003, u_first=[2.137, 2.279], angle=+0.022, ang_vel=+0.266
# [NMPC] get_Constraints failed at t=4, it=0: name 'get_Constraints' is not defined
# [NMPC] t=004, u_first=[2.142, 2.273], angle=+0.033, ang_vel=+0.257
# [NMPC] get_Constraints failed at t=5, it=0: name 'get_Constraints' is not defined
# [NMPC] t=005, u_first=[2.152, 2.262], angle=+0.043, ang_vel=+0.249
# [NMPC] get_Constraints failed at t=6, it=0: name 'get_Constraints' is not defined
# [NMPC] t=006, u_first=[2.165, 2.249], angle=+0.053, ang_vel=+0.242
# [NMPC] get_Constraints failed at t=7, it=0: name 'get_Constraints' is not defined
# [NMPC] t=007, u_first=[2.181, 2.232], angle=+0.063, ang_vel=+0.237
# [NMPC] get_Constraints failed at t=8, it=0: name 'get_Constraints' is not defined
# [NMPC] t=008, u_first=[2.199, 2.213], angle=+0.072, ang_vel=+0.234
# [NMPC] get_Constraints failed at t=9, it=0: name 'get_Constraints' is not defined
# [NMPC] t=009, u_first=[2.219, 2.193], angle=+0.082, ang_vel=+0.233
# [NMPC] get_Constraints failed at t=10, it=0: name 'get_Constraints' is not defined
# [NMPC] t=010, u_first=[2.241, 2.171], angle=+0.091, ang_vel=+0.234
# [NMPC] get_Constraints failed at t=11, it=0: name 'get_Constraints' is not defined
# [NMPC] t=011, u_first=[2.263, 2.149], angle=+0.100, ang_vel=+0.239
# [NMPC] get_Constraints failed at t=12, it=0: name 'get_Constraints' is not defined
# [NMPC] t=012, u_first=[2.286, 2.127], angle=+0.110, ang_vel=+0.246
# [NMPC] get_Constraints failed at t=13, it=0: name 'get_Constraints' is not defined
# [NMPC] t=013, u_first=[2.309, 2.105], angle=+0.120, ang_vel=+0.256
# [NMPC] get_Constraints failed at t=14, it=0: name 'get_Constraints' is not defined
# [NMPC] t=014, u_first=[2.331, 2.085], angle=+0.130, ang_vel=+0.268
# [NMPC] get_Constraints failed at t=15, it=0: name 'get_Constraints' is not defined
# [NMPC] t=015, u_first=[2.351, 2.066], angle=+0.141, ang_vel=+0.284
# [NMPC] get_Constraints failed at t=16, it=0: name 'get_Constraints' is not defined
# [NMPC] t=016, u_first=[2.370, 2.048], angle=+0.152, ang_vel=+0.301
# [NMPC] get_Constraints failed at t=17, it=0: name 'get_Constraints' is not defined
# [NMPC] t=017, u_first=[2.386, 2.033], angle=+0.164, ang_vel=+0.321
# [NMPC] get_Constraints failed at t=18, it=0: name 'get_Constraints' is not defined
# [NMPC] t=018, u_first=[2.398, 2.021], angle=+0.177, ang_vel=+0.343
# [NMPC] get_Constraints failed at t=19, it=0: name 'get_Constraints' is not defined
# [NMPC] t=019, u_first=[2.407, 2.012], angle=+0.191, ang_vel=+0.367
# [NMPC] get_Constraints failed at t=20, it=0: name 'get_Constraints' is not defined
# [NMPC] t=020, u_first=[2.413, 2.007], angle=+0.205, ang_vel=+0.391
# [NMPC] get_Constraints failed at t=21, it=0: name 'get_Constraints' is not defined
# [NMPC] t=021, u_first=[2.416, 2.010], angle=+0.221, ang_vel=+0.417
# [NMPC] get_Constraints failed at t=22, it=0: name 'get_Constraints' is not defined
# [NMPC] t=022, u_first=[2.414, 2.016], angle=+0.238, ang_vel=+0.442
# [NMPC] get_Constraints failed at t=23, it=0: name 'get_Constraints' is not defined
# [NMPC] t=023, u_first=[2.406, 2.026], angle=+0.255, ang_vel=+0.467
# [NMPC] get_Constraints failed at t=24, it=0: name 'get_Constraints' is not defined
# [NMPC] t=024, u_first=[2.391, 2.042], angle=+0.274, ang_vel=+0.490
# [NMPC] get_Constraints failed at t=25, it=0: name 'get_Constraints' is not defined
# [NMPC] t=025, u_first=[2.369, 2.062], angle=+0.294, ang_vel=+0.512
# [NMPC] get_Constraints failed at t=26, it=0: name 'get_Constraints' is not defined
# [NMPC] t=026, u_first=[2.340, 2.087], angle=+0.314, ang_vel=+0.635
# [NMPC] get_Constraints failed at t=27, it=0: name 'get_Constraints' is not defined
# [NMPC] t=027, u_first=[2.305, 2.118], angle=+0.340, ang_vel=+0.651
# [NMPC] get_Constraints failed at t=28, it=0: name 'get_Constraints' is not defined
# [NMPC] t=028, u_first=[2.263, 2.155], angle=+0.366, ang_vel=+0.663
# [NMPC] get_Constraints failed at t=29, it=0: name 'get_Constraints' is not defined
# [NMPC] t=029, u_first=[2.215, 2.197], angle=+0.392, ang_vel=+0.670
# [NMPC] get_Constraints failed at t=30, it=0: name 'get_Constraints' is not defined
# [NMPC] t=030, u_first=[2.161, 2.245], angle=+0.419, ang_vel=+0.671
# [NMPC] get_Constraints failed at t=31, it=0: name 'get_Constraints' is not defined
# [NMPC] t=031, u_first=[2.102, 2.299], angle=+0.446, ang_vel=+0.665
# [NMPC] get_Constraints failed at t=32, it=0: name 'get_Constraints' is not defined
# [NMPC] t=032, u_first=[2.039, 2.359], angle=+0.472, ang_vel=+0.653
# [NMPC] get_Constraints failed at t=33, it=0: name 'get_Constraints' is not defined
# [NMPC] t=033, u_first=[1.973, 2.424], angle=+0.498, ang_vel=+0.633
# [NMPC] get_Constraints failed at t=34, it=0: name 'get_Constraints' is not defined
# [NMPC] t=034, u_first=[1.973, 2.424], angle=+0.524, ang_vel=+0.605
# [NMPC] get_Constraints failed at t=35, it=0: name 'get_Constraints' is not defined
# [NMPC] t=035, u_first=[1.906, 2.493], angle=+0.548, ang_vel=+0.577
# [NMPC] get_Constraints failed at t=36, it=0: name 'get_Constraints' is not defined
# [NMPC] t=036, u_first=[1.838, 2.567], angle=+0.571, ang_vel=+0.540
# [NMPC] get_Constraints failed at t=37, it=0: name 'get_Constraints' is not defined
# [NMPC] t=037, u_first=[1.772, 2.643], angle=+0.593, ang_vel=+0.495
# [NMPC] get_Constraints failed at t=38, it=0: name 'get_Constraints' is not defined
# [NMPC] t=038, u_first=[1.708, 2.721], angle=+0.612, ang_vel=+0.441
# [NMPC] get_Constraints failed at t=39, it=0: name 'get_Constraints' is not defined
# [NMPC] t=039, u_first=[1.648, 2.797], angle=+0.630, ang_vel=+0.378
# [NMPC] get_Constraints failed at t=40, it=0: name 'get_Constraints' is not defined
# [NMPC] t=040, u_first=[1.592, 2.869], angle=+0.645, ang_vel=+0.306
# [NMPC] get_Constraints failed at t=41, it=0: name 'get_Constraints' is not defined
# [NMPC] t=041, u_first=[1.541, 2.933], angle=+0.657, ang_vel=+0.227
# [NMPC] get_Constraints failed at t=42, it=0: name 'get_Constraints' is not defined
# [NMPC] t=042, u_first=[1.495, 2.985], angle=+0.667, ang_vel=+0.140
# [NMPC] get_Constraints failed at t=43, it=0: name 'get_Constraints' is not defined
# [NMPC] t=043, u_first=[1.454, 3.021], angle=+0.672, ang_vel=+0.048
# [NMPC] get_Constraints failed at t=44, it=0: name 'get_Constraints' is not defined
# [NMPC] t=044, u_first=[1.418, 3.034], angle=+0.674, ang_vel=-0.050
# [NMPC] get_Constraints failed at t=45, it=0: name 'get_Constraints' is not defined
# [NMPC] t=045, u_first=[1.427, 3.061], angle=+0.672, ang_vel=-0.150
# [NMPC] get_Constraints failed at t=46, it=0: name 'get_Constraints' is not defined
# [NMPC] t=046, u_first=[1.526, 3.140], angle=+0.666, ang_vel=-0.252
# [NMPC] get_Constraints failed at t=47, it=0: name 'get_Constraints' is not defined
# [NMPC] t=047, u_first=[1.631, 3.179], angle=+0.656, ang_vel=-0.353
# [NMPC] get_Constraints failed at t=48, it=0: name 'get_Constraints' is not defined
# [NMPC] t=048, u_first=[1.743, 3.173], angle=+0.642, ang_vel=-0.449
# [NMPC] get_Constraints failed at t=49, it=0: name 'get_Constraints' is not defined
# [NMPC] t=049, u_first=[1.863, 3.115], angle=+0.624, ang_vel=-0.538
# [NMPC] get_Constraints failed at t=50, it=0: name 'get_Constraints' is not defined
# [NMPC] t=050, u_first=[1.990, 3.000], angle=+0.602, ang_vel=-0.616
# [NMPC] get_Constraints failed at t=51, it=0: name 'get_Constraints' is not defined
# [NMPC] t=051, u_first=[2.126, 2.824], angle=+0.578, ang_vel=-1.011
# [NMPC] get_Constraints failed at t=52, it=0: name 'get_Constraints' is not defined
# [NMPC] t=052, u_first=[2.270, 2.583], angle=+0.537, ang_vel=-1.054
# [NMPC] get_Constraints failed at t=53, it=0: name 'get_Constraints' is not defined
# [NMPC] t=053, u_first=[2.422, 2.276], angle=+0.495, ang_vel=-1.074
# [NMPC] get_Constraints failed at t=54, it=0: name 'get_Constraints' is not defined
# [NMPC] t=054, u_first=[2.582, 1.903], angle=+0.452, ang_vel=-1.065
# [NMPC] get_Constraints failed at t=55, it=0: name 'get_Constraints' is not defined
# [NMPC] t=055, u_first=[2.752, 1.469], angle=+0.410, ang_vel=-1.023
# [NMPC] get_Constraints failed at t=56, it=0: name 'get_Constraints' is not defined
# [NMPC] t=056, u_first=[2.934, 0.978], angle=+0.369, ang_vel=-0.943
# [NMPC] get_Constraints failed at t=57, it=0: name 'get_Constraints' is not defined
# [NMPC] t=057, u_first=[3.129, 0.440], angle=+0.331, ang_vel=-0.821
# [NMPC] get_Constraints failed at t=58, it=0: name 'get_Constraints' is not defined
# [NMPC] t=058, u_first=[3.340, 0.000], angle=+0.298, ang_vel=-0.654
# [NMPC] get_Constraints failed at t=59, it=0: name 'get_Constraints' is not defined
# [NMPC] t=059, u_first=[3.575, 0.000], angle=+0.272, ang_vel=-0.446
# [NMPC] get_Constraints failed at t=60, it=0: name 'get_Constraints' is not defined
# [NMPC] t=060, u_first=[3.835, 0.000], angle=+0.254, ang_vel=-0.224
# [NMPC] get_Constraints failed at t=61, it=0: name 'get_Constraints' is not defined
# [NMPC] t=061, u_first=[4.117, 0.000], angle=+0.245, ang_vel=+0.015
# [NMPC] get_Constraints failed at t=62, it=0: name 'get_Constraints' is not defined
# [NMPC] t=062, u_first=[4.412, 0.000], angle=+0.246, ang_vel=+0.271
# [NMPC] get_Constraints failed at t=63, it=0: name 'get_Constraints' is not defined
# [NMPC] t=063, u_first=[4.705, 0.000], angle=+0.257, ang_vel=+0.546
# [NMPC] get_Constraints failed at t=64, it=0: name 'get_Constraints' is not defined
# [NMPC] t=064, u_first=[4.978, 0.000], angle=+0.279, ang_vel=+0.839
# [NMPC] get_Constraints failed at t=65, it=0: name 'get_Constraints' is not defined
# [NMPC] t=065, u_first=[5.206, 0.000], angle=+0.312, ang_vel=+1.148
# [NMPC] get_Constraints failed at t=66, it=0: name 'get_Constraints' is not defined
# [NMPC] t=066, u_first=[5.361, 0.000], angle=+0.358, ang_vel=+1.472
# [NMPC] get_Constraints failed at t=67, it=0: name 'get_Constraints' is not defined
# [NMPC] t=067, u_first=[5.418, 0.000], angle=+0.417, ang_vel=+1.806
# [NMPC] get_Constraints failed at t=68, it=0: name 'get_Constraints' is not defined
# [NMPC] t=068, u_first=[5.353, 0.000], angle=+0.489, ang_vel=+2.143
# [NMPC] get_Constraints failed at t=69, it=0: name 'get_Constraints' is not defined
# [NMPC] t=069, u_first=[5.154, 0.000], angle=+0.575, ang_vel=+2.476
# [NMPC] get_Constraints failed at t=70, it=0: name 'get_Constraints' is not defined
# [NMPC] t=070, u_first=[4.826, 0.000], angle=+0.674, ang_vel=+2.797
# [NMPC] get_Constraints failed at t=71, it=0: name 'get_Constraints' is not defined
# [NMPC] t=071, u_first=[8.703, 0.000], angle=+0.786, ang_vel=+3.097
# [NMPC] get_Constraints failed at t=72, it=0: name 'get_Constraints' is not defined
# [NMPC] t=072, u_first=[10.000, 0.000], angle=+0.910, ang_vel=+3.639
# [NMPC] get_Constraints failed at t=73, it=0: name 'get_Constraints' is not defined
# [NMPC] t=073, u_first=[10.000, 0.000], angle=+1.055, ang_vel=+4.261
# [NMPC] get_Constraints failed at t=74, it=0: name 'get_Constraints' is not defined
# [NMPC] t=074, u_first=[10.000, 1.228], angle=+1.226, ang_vel=+4.883
# [NMPC] get_Constraints failed at t=75, it=0: name 'get_Constraints' is not defined
# [NMPC] t=075, u_first=[10.000, 2.759], angle=+1.421, ang_vel=+5.429
# [NMPC] get_Constraints failed at t=76, it=0: name 'get_Constraints' is not defined
# [NMPC] t=076, u_first=[10.000, 3.226], angle=+1.638, ang_vel=+5.775
# [NMPC] get_Constraints failed at t=77, it=0: name 'get_Constraints' is not defined
# [NMPC] t=077, u_first=[10.000, 2.398], angle=+1.869, ang_vel=+6.196
# [NMPC] get_Constraints failed at t=78, it=0: name 'get_Constraints' is not defined
# [NMPC] t=078, u_first=[5.379, 0.000], angle=+2.117, ang_vel=+6.669
# [NMPC] get_Constraints failed at t=79, it=0: name 'get_Constraints' is not defined
# [NMPC] t=079, u_first=[0.000, 0.000], angle=+2.384, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=80, it=0: name 'get_Constraints' is not defined
# [NMPC] t=080, u_first=[0.000, 0.000], angle=+2.664, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=81, it=0: name 'get_Constraints' is not defined
# [NMPC] t=081, u_first=[0.000, 0.000], angle=+2.944, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=82, it=0: name 'get_Constraints' is not defined
# [NMPC] t=082, u_first=[0.000, 0.000], angle=+3.224, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=83, it=0: name 'get_Constraints' is not defined
# [NMPC] t=083, u_first=[0.000, 0.000], angle=+3.504, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=84, it=0: name 'get_Constraints' is not defined
# [NMPC] t=084, u_first=[0.000, 0.000], angle=+3.784, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=85, it=0: name 'get_Constraints' is not defined
# [NMPC] t=085, u_first=[0.000, 0.000], angle=+4.065, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=86, it=0: name 'get_Constraints' is not defined
# [NMPC] t=086, u_first=[0.000, 0.000], angle=+4.345, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=87, it=0: name 'get_Constraints' is not defined
# [NMPC] t=087, u_first=[0.000, 0.000], angle=+4.625, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=88, it=0: name 'get_Constraints' is not defined
# [NMPC] t=088, u_first=[0.000, 0.000], angle=+4.905, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=89, it=0: name 'get_Constraints' is not defined
# [NMPC] t=089, u_first=[0.000, 6.718], angle=+5.185, ang_vel=+7.004
# [NMPC] get_Constraints failed at t=90, it=0: name 'get_Constraints' is not defined
# [NMPC] t=090, u_first=[0.000, 10.000], angle=+5.465, ang_vel=+6.586
# [NMPC] get_Constraints failed at t=91, it=0: name 'get_Constraints' is not defined
# [NMPC] t=091, u_first=[0.000, 10.000], angle=+5.729, ang_vel=+5.964
# [NMPC] get_Constraints failed at t=92, it=0: name 'get_Constraints' is not defined
# [NMPC] t=092, u_first=[0.000, 10.000], angle=+5.967, ang_vel=+5.341
# [NMPC] get_Constraints failed at t=93, it=0: name 'get_Constraints' is not defined
# [NMPC] t=093, u_first=[0.000, 10.000], angle=+6.181, ang_vel=+4.719
# [NMPC] get_Constraints failed at t=94, it=0: name 'get_Constraints' is not defined
# [NMPC] t=094, u_first=[0.000, 10.000], angle=+6.370, ang_vel=+4.097
# [NMPC] get_Constraints failed at t=95, it=0: name 'get_Constraints' is not defined
# [NMPC] t=095, u_first=[0.000, 10.000], angle=+6.534, ang_vel=+3.475
# [NMPC] get_Constraints failed at t=96, it=0: name 'get_Constraints' is not defined
# [NMPC] t=096, u_first=[0.000, 10.000], angle=+6.673, ang_vel=+2.853
# [NMPC] get_Constraints failed at t=97, it=0: name 'get_Constraints' is not defined
# [NMPC] t=097, u_first=[0.000, 10.000], angle=+6.787, ang_vel=+2.230
# [NMPC] get_Constraints failed at t=98, it=0: name 'get_Constraints' is not defined
# [NMPC] t=098, u_first=[0.000, 10.000], angle=+6.876, ang_vel=+1.608
# [NMPC] get_Constraints failed at t=99, it=0: name 'get_Constraints' is not defined
# [NMPC] t=099, u_first=[0.000, 8.158], angle=+6.940, ang_vel=+0.986
# [NMPC] get_Constraints failed at t=100, it=0: name 'get_Constraints' is not defined
# [NMPC] t=100, u_first=[0.000, 8.158], angle=+6.980, ang_vel=+0.478
# [NMPC] get_Constraints failed at t=101, it=0: name 'get_Constraints' is not defined
# [NMPC] t=101, u_first=[0.000, 8.158], angle=+6.999, ang_vel=-0.335
# [NMPC] get_Constraints failed at t=102, it=0: name 'get_Constraints' is not defined
# [NMPC] t=102, u_first=[0.000, 8.158], angle=+6.985, ang_vel=-0.842
# [NMPC] get_Constraints failed at t=103, it=0: name 'get_Constraints' is not defined
# [NMPC] t=103, u_first=[0.000, 8.158], angle=+6.952, ang_vel=-1.350
# [NMPC] get_Constraints failed at t=104, it=0: name 'get_Constraints' is not defined
# [NMPC] t=104, u_first=[0.000, 8.158], angle=+6.898, ang_vel=-1.858
# [NMPC] get_Constraints failed at t=105, it=0: name 'get_Constraints' is not defined
# [NMPC] t=105, u_first=[0.000, 8.158], angle=+6.824, ang_vel=-2.365
# [NMPC] get_Constraints failed at t=106, it=0: name 'get_Constraints' is not defined
# [NMPC] t=106, u_first=[0.000, 8.158], angle=+6.729, ang_vel=-2.873
# [NMPC] get_Constraints failed at t=107, it=0: name 'get_Constraints' is not defined
# [NMPC] t=107, u_first=[0.000, 8.158], angle=+6.614, ang_vel=-3.380
# [NMPC] get_Constraints failed at t=108, it=0: name 'get_Constraints' is not defined
# [NMPC] t=108, u_first=[0.000, 8.158], angle=+6.479, ang_vel=-3.888
# [NMPC] get_Constraints failed at t=109, it=0: name 'get_Constraints' is not defined
# [NMPC] t=109, u_first=[0.000, 8.158], angle=+6.323, ang_vel=-4.396
# [NMPC] get_Constraints failed at t=110, it=0: name 'get_Constraints' is not defined
# [NMPC] t=110, u_first=[0.000, 8.158], angle=+6.147, ang_vel=-4.903
# [NMPC] get_Constraints failed at t=111, it=0: name 'get_Constraints' is not defined
# [NMPC] t=111, u_first=[0.000, 8.158], angle=+5.951, ang_vel=-5.411
# [NMPC] get_Constraints failed at t=112, it=0: name 'get_Constraints' is not defined
# [NMPC] t=112, u_first=[0.000, 8.158], angle=+5.735, ang_vel=-5.918
# [NMPC] get_Constraints failed at t=113, it=0: name 'get_Constraints' is not defined
# [NMPC] t=113, u_first=[0.000, 8.158], angle=+5.498, ang_vel=-6.426
# [NMPC] get_Constraints failed at t=114, it=0: name 'get_Constraints' is not defined
# [NMPC] t=114, u_first=[0.000, 8.158], angle=+5.241, ang_vel=-6.934
# [NMPC] get_Constraints failed at t=115, it=0: name 'get_Constraints' is not defined
# [NMPC] t=115, u_first=[0.000, 8.158], angle=+4.964, ang_vel=-7.441
# [NMPC] get_Constraints failed at t=116, it=0: name 'get_Constraints' is not defined
# [NMPC] t=116, u_first=[0.000, 8.158], angle=+4.666, ang_vel=-7.949
# [NMPC] get_Constraints failed at t=117, it=0: name 'get_Constraints' is not defined
# [NMPC] t=117, u_first=[0.000, 8.158], angle=+4.348, ang_vel=-8.456
# [NMPC] get_Constraints failed at t=118, it=0: name 'get_Constraints' is not defined
# [NMPC] t=118, u_first=[0.000, 8.158], angle=+4.010, ang_vel=-8.964
# [NMPC] get_Constraints failed at t=119, it=0: name 'get_Constraints' is not defined
# [NMPC] t=119, u_first=[0.000, 8.158], angle=+3.651, ang_vel=-9.472
# [NMPC] get_Constraints failed at t=120, it=0: name 'get_Constraints' is not defined
# [NMPC] t=120, u_first=[0.000, 8.158], angle=+3.273, ang_vel=-9.979
# [NMPC] get_Constraints failed at t=121, it=0: name 'get_Constraints' is not defined
# [NMPC] t=121, u_first=[0.000, 8.158], angle=+2.873, ang_vel=-10.487
# [NMPC] get_Constraints failed at t=122, it=0: name 'get_Constraints' is not defined
# [NMPC] t=122, u_first=[0.000, 8.158], angle=+2.454, ang_vel=-10.994
# [NMPC] get_Constraints failed at t=123, it=0: name 'get_Constraints' is not defined
# [NMPC] t=123, u_first=[0.000, 8.158], angle=+2.014, ang_vel=-11.502
# [NMPC] get_Constraints failed at t=124, it=0: name 'get_Constraints' is not defined
# [NMPC] t=124, u_first=[0.000, 8.158], angle=+1.554, ang_vel=-12.010
# [NMPC] get_Constraints failed at t=125, it=0: name 'get_Constraints' is not defined
# [NMPC] t=125, u_first=[0.000, 8.158], angle=+1.074, ang_vel=-12.517
# [NMPC] get_Constraints failed at t=126, it=0: name 'get_Constraints' is not defined
# [NMPC] t=126, u_first=[0.000, 8.158], angle=+0.573, ang_vel=-12.937
# [NMPC] get_Constraints failed at t=127, it=0: name 'get_Constraints' is not defined
# [NMPC] t=127, u_first=[0.000, 8.158], angle=+0.055, ang_vel=-13.445
# [NMPC] get_Constraints failed at t=128, it=0: name 'get_Constraints' is not defined
# [NMPC] t=128, u_first=[0.000, 8.158], angle=-0.482, ang_vel=-13.953
# [NMPC] get_Constraints failed at t=129, it=0: name 'get_Constraints' is not defined
# [NMPC] t=129, u_first=[0.000, 8.158], angle=-1.040, ang_vel=-14.460
# [NMPC] get_Constraints failed at t=130, it=0: name 'get_Constraints' is not defined
# [NMPC] t=130, u_first=[0.000, 8.158], angle=-1.619, ang_vel=-14.968
# [NMPC] get_Constraints failed at t=131, it=0: name 'get_Constraints' is not defined
# [NMPC] t=131, u_first=[0.000, 8.158], angle=-2.218, ang_vel=-15.475
# [NMPC] get_Constraints failed at t=132, it=0: name 'get_Constraints' is not defined
# [NMPC] t=132, u_first=[0.000, 8.158], angle=-2.837, ang_vel=-15.983
# [NMPC] get_Constraints failed at t=133, it=0: name 'get_Constraints' is not defined
# [NMPC] t=133, u_first=[0.000, 8.158], angle=-3.476, ang_vel=-16.491
# [NMPC] get_Constraints failed at t=134, it=0: name 'get_Constraints' is not defined
# [NMPC] t=134, u_first=[0.000, 8.158], angle=-4.136, ang_vel=-16.998
# [NMPC] get_Constraints failed at t=135, it=0: name 'get_Constraints' is not defined
# [NMPC] t=135, u_first=[0.000, 8.158], angle=-4.815, ang_vel=-17.506
# [NMPC] get_Constraints failed at t=136, it=0: name 'get_Constraints' is not defined
# [NMPC] t=136, u_first=[0.000, 8.158], angle=-5.516, ang_vel=-18.013
# [NMPC] get_Constraints failed at t=137, it=0: name 'get_Constraints' is not defined
# [NMPC] t=137, u_first=[0.000, 8.158], angle=-6.236, ang_vel=-18.521
# [NMPC] get_Constraints failed at t=138, it=0: name 'get_Constraints' is not defined
# [NMPC] t=138, u_first=[0.000, 8.158], angle=-6.977, ang_vel=-19.029
# [NMPC] get_Constraints failed at t=139, it=0: name 'get_Constraints' is not defined
# [NMPC] t=139, u_first=[0.000, 8.158], angle=-7.738, ang_vel=-19.536
# [NMPC] get_Constraints failed at t=140, it=0: name 'get_Constraints' is not defined
# [NMPC] t=140, u_first=[0.000, 8.158], angle=-8.520, ang_vel=-20.044
# [NMPC] get_Constraints failed at t=141, it=0: name 'get_Constraints' is not defined
# [NMPC] t=141, u_first=[0.000, 8.158], angle=-9.321, ang_vel=-20.551
# [NMPC] get_Constraints failed at t=142, it=0: name 'get_Constraints' is not defined
# [NMPC] t=142, u_first=[0.000, 8.158], angle=-10.143, ang_vel=-21.059
# [NMPC] get_Constraints failed at t=143, it=0: name 'get_Constraints' is not defined
# [NMPC] t=143, u_first=[0.000, 8.158], angle=-10.986, ang_vel=-21.567
# [NMPC] get_Constraints failed at t=144, it=0: name 'get_Constraints' is not defined
# [NMPC] t=144, u_first=[0.000, 8.158], angle=-11.849, ang_vel=-22.074
# [NMPC] get_Constraints failed at t=145, it=0: name 'get_Constraints' is not defined
# [NMPC] t=145, u_first=[0.000, 8.158], angle=-12.731, ang_vel=-22.582
# [NMPC] get_Constraints failed at t=146, it=0: name 'get_Constraints' is not defined
# [NMPC] t=146, u_first=[0.000, 8.158], angle=-13.635, ang_vel=-23.089
# [NMPC] get_Constraints failed at t=147, it=0: name 'get_Constraints' is not defined
# [NMPC] t=147, u_first=[0.000, 8.158], angle=-14.558, ang_vel=-23.597
# [NMPC] get_Constraints failed at t=148, it=0: name 'get_Constraints' is not defined
# [NMPC] t=148, u_first=[0.000, 8.158], angle=-15.502, ang_vel=-24.105
# [NMPC] get_Constraints failed at t=149, it=0: name 'get_Constraints' is not defined
# [NMPC] t=149, u_first=[0.000, 8.158], angle=-16.466, ang_vel=-24.612
# [NMPC] get_Constraints failed at t=150, it=0: name 'get_Constraints' is not defined
# [NMPC] t=150, u_first=[0.000, 8.158], angle=-17.451, ang_vel=-25.120
# [NMPC] get_Constraints failed at t=151, it=0: name 'get_Constraints' is not defined
# [NMPC] t=151, u_first=[0.000, 8.158], angle=-18.456, ang_vel=-24.642
# [NMPC] get_Constraints failed at t=152, it=0: name 'get_Constraints' is not defined
# [NMPC] t=152, u_first=[0.000, 8.158], angle=-19.441, ang_vel=-25.150
# [NMPC] get_Constraints failed at t=153, it=0: name 'get_Constraints' is not defined
# [NMPC] t=153, u_first=[0.000, 8.158], angle=-20.447, ang_vel=-25.658
# [NMPC] get_Constraints failed at t=154, it=0: name 'get_Constraints' is not defined
# [NMPC] t=154, u_first=[0.000, 8.158], angle=-21.474, ang_vel=-26.165
# [NMPC] get_Constraints failed at t=155, it=0: name 'get_Constraints' is not defined
# [NMPC] t=155, u_first=[0.000, 8.158], angle=-22.520, ang_vel=-26.673
# [NMPC] get_Constraints failed at t=156, it=0: name 'get_Constraints' is not defined
# [NMPC] t=156, u_first=[0.000, 8.158], angle=-23.587, ang_vel=-27.180
# [NMPC] get_Constraints failed at t=157, it=0: name 'get_Constraints' is not defined
# [NMPC] t=157, u_first=[0.000, 8.158], angle=-24.674, ang_vel=-27.688
# [NMPC] get_Constraints failed at t=158, it=0: name 'get_Constraints' is not defined
# [NMPC] t=158, u_first=[0.000, 8.158], angle=-25.782, ang_vel=-28.196
# [NMPC] get_Constraints failed at t=159, it=0: name 'get_Constraints' is not defined
# [NMPC] t=159, u_first=[0.000, 8.158], angle=-26.910, ang_vel=-28.703
# [NMPC] get_Constraints failed at t=160, it=0: name 'get_Constraints' is not defined
# [NMPC] t=160, u_first=[0.000, 8.158], angle=-28.058, ang_vel=-29.211
# [NMPC] get_Constraints failed at t=161, it=0: name 'get_Constraints' is not defined
# [NMPC] t=161, u_first=[0.000, 8.158], angle=-29.226, ang_vel=-29.718
# [NMPC] get_Constraints failed at t=162, it=0: name 'get_Constraints' is not defined
# [NMPC] t=162, u_first=[0.000, 8.158], angle=-30.415, ang_vel=-30.226
# [NMPC] get_Constraints failed at t=163, it=0: name 'get_Constraints' is not defined
# [NMPC] t=163, u_first=[0.000, 8.158], angle=-31.624, ang_vel=-30.734
# [NMPC] get_Constraints failed at t=164, it=0: name 'get_Constraints' is not defined
# [NMPC] t=164, u_first=[0.000, 8.158], angle=-32.853, ang_vel=-31.241
# [NMPC] get_Constraints failed at t=165, it=0: name 'get_Constraints' is not defined
# [NMPC] t=165, u_first=[0.000, 8.158], angle=-34.103, ang_vel=-31.749
# [NMPC] get_Constraints failed at t=166, it=0: name 'get_Constraints' is not defined
# [NMPC] t=166, u_first=[0.000, 8.158], angle=-35.373, ang_vel=-32.256
# [NMPC] get_Constraints failed at t=167, it=0: name 'get_Constraints' is not defined
# [NMPC] t=167, u_first=[0.000, 8.158], angle=-36.663, ang_vel=-32.764
# [NMPC] get_Constraints failed at t=168, it=0: name 'get_Constraints' is not defined
# [NMPC] t=168, u_first=[0.000, 8.158], angle=-37.974, ang_vel=-33.272
# [NMPC] get_Constraints failed at t=169, it=0: name 'get_Constraints' is not defined
# [NMPC] t=169, u_first=[0.000, 8.158], angle=-39.305, ang_vel=-33.779
# [NMPC] get_Constraints failed at t=170, it=0: name 'get_Constraints' is not defined
# [NMPC] t=170, u_first=[0.000, 8.158], angle=-40.656, ang_vel=-34.287
# [NMPC] get_Constraints failed at t=171, it=0: name 'get_Constraints' is not defined
# [NMPC] t=171, u_first=[0.000, 8.158], angle=-42.027, ang_vel=-34.794
# [NMPC] get_Constraints failed at t=172, it=0: name 'get_Constraints' is not defined
# [NMPC] t=172, u_first=[0.000, 8.158], angle=-43.419, ang_vel=-35.302
# [NMPC] get_Constraints failed at t=173, it=0: name 'get_Constraints' is not defined
# [NMPC] t=173, u_first=[0.000, 8.158], angle=-44.831, ang_vel=-35.810
# [NMPC] get_Constraints failed at t=174, it=0: name 'get_Constraints' is not defined
# [NMPC] t=174, u_first=[0.000, 8.158], angle=-46.264, ang_vel=-36.317
# [NMPC] get_Constraints failed at t=175, it=0: name 'get_Constraints' is not defined
# [NMPC] t=175, u_first=[0.000, 8.158], angle=-47.716, ang_vel=-36.825
# [NMPC] get_Constraints failed at t=176, it=0: name 'get_Constraints' is not defined
# [NMPC] t=176, u_first=[0.000, 8.158], angle=-49.189, ang_vel=-37.781
# [NMPC] get_Constraints failed at t=177, it=0: name 'get_Constraints' is not defined
# [NMPC] t=177, u_first=[0.000, 8.158], angle=-50.701, ang_vel=-38.289
# [NMPC] get_Constraints failed at t=178, it=0: name 'get_Constraints' is not defined
# [NMPC] t=178, u_first=[0.000, 8.158], angle=-52.232, ang_vel=-38.796
# [NMPC] get_Constraints failed at t=179, it=0: name 'get_Constraints' is not defined
# [NMPC] t=179, u_first=[0.000, 8.158], angle=-53.784, ang_vel=-39.304
# [NMPC] get_Constraints failed at t=180, it=0: name 'get_Constraints' is not defined
# [NMPC] t=180, u_first=[0.000, 8.158], angle=-55.356, ang_vel=-39.812
# [NMPC] get_Constraints failed at t=181, it=0: name 'get_Constraints' is not defined
# [NMPC] t=181, u_first=[0.000, 8.158], angle=-56.949, ang_vel=-40.319
# [NMPC] get_Constraints failed at t=182, it=0: name 'get_Constraints' is not defined
# [NMPC] t=182, u_first=[0.000, 8.158], angle=-58.561, ang_vel=-40.827
# [NMPC] get_Constraints failed at t=183, it=0: name 'get_Constraints' is not defined
# [NMPC] t=183, u_first=[0.000, 8.158], angle=-60.194, ang_vel=-41.334
# [NMPC] get_Constraints failed at t=184, it=0: name 'get_Constraints' is not defined
# [NMPC] t=184, u_first=[0.000, 8.158], angle=-61.848, ang_vel=-41.842
# [NMPC] get_Constraints failed at t=185, it=0: name 'get_Constraints' is not defined
# [NMPC] t=185, u_first=[0.000, 8.158], angle=-63.521, ang_vel=-42.350
# [NMPC] get_Constraints failed at t=186, it=0: name 'get_Constraints' is not defined
# [NMPC] t=186, u_first=[0.000, 8.158], angle=-65.215, ang_vel=-42.857
# [NMPC] get_Constraints failed at t=187, it=0: name 'get_Constraints' is not defined
# [NMPC] t=187, u_first=[0.000, 8.158], angle=-66.930, ang_vel=-43.365
# [NMPC] get_Constraints failed at t=188, it=0: name 'get_Constraints' is not defined
# [NMPC] t=188, u_first=[0.000, 8.158], angle=-68.664, ang_vel=-43.872
# [NMPC] get_Constraints failed at t=189, it=0: name 'get_Constraints' is not defined
# [NMPC] t=189, u_first=[0.000, 8.158], angle=-70.419, ang_vel=-44.380
# [NMPC] get_Constraints failed at t=190, it=0: name 'get_Constraints' is not defined
# [NMPC] t=190, u_first=[0.000, 8.158], angle=-72.194, ang_vel=-44.888
# [NMPC] get_Constraints failed at t=191, it=0: name 'get_Constraints' is not defined
# [NMPC] t=191, u_first=[0.000, 8.158], angle=-73.990, ang_vel=-45.395
# [NMPC] get_Constraints failed at t=192, it=0: name 'get_Constraints' is not defined
# [NMPC] t=192, u_first=[0.000, 8.158], angle=-75.806, ang_vel=-45.903
# [NMPC] get_Constraints failed at t=193, it=0: name 'get_Constraints' is not defined
# [NMPC] t=193, u_first=[0.000, 8.158], angle=-77.642, ang_vel=-46.410
# [NMPC] get_Constraints failed at t=194, it=0: name 'get_Constraints' is not defined
# [NMPC] t=194, u_first=[0.000, 8.158], angle=-79.498, ang_vel=-46.918
# [NMPC] get_Constraints failed at t=195, it=0: name 'get_Constraints' is not defined
# [NMPC] t=195, u_first=[0.000, 8.158], angle=-81.375, ang_vel=-47.426
# [NMPC] get_Constraints failed at t=196, it=0: name 'get_Constraints' is not defined
# [NMPC] t=196, u_first=[0.000, 8.158], angle=-83.272, ang_vel=-47.933
# [NMPC] get_Constraints failed at t=197, it=0: name 'get_Constraints' is not defined
# [NMPC] t=197, u_first=[0.000, 8.158], angle=-85.189, ang_vel=-48.441
# [NMPC] get_Constraints failed at t=198, it=0: name 'get_Constraints' is not defined
# [NMPC] t=198, u_first=[0.000, 8.158], angle=-87.127, ang_vel=-48.948
# [NMPC] get_Constraints failed at t=199, it=0: name 'get_Constraints' is not defined
# [NMPC] t=199, u_first=[0.000, 8.158], angle=-89.085, ang_vel=-49.456
# [NMPC] get_Constraints failed at t=200, it=0: name 'get_Constraints' is not defined
# [NMPC] t=200, u_first=[0.000, 8.158], angle=-91.063, ang_vel=-49.964
# [NMPC] get_Constraints failed at t=201, it=0: name 'get_Constraints' is not defined
# [NMPC] t=201, u_first=[0.000, 8.158], angle=-93.062, ang_vel=-50.527
# [NMPC] get_Constraints failed at t=202, it=0: name 'get_Constraints' is not defined
# [NMPC] t=202, u_first=[0.000, 8.158], angle=-95.083, ang_vel=-51.034
# [NMPC] get_Constraints failed at t=203, it=0: name 'get_Constraints' is not defined
# [NMPC] t=203, u_first=[0.000, 8.158], angle=-97.124, ang_vel=-51.542
# [NMPC] get_Constraints failed at t=204, it=0: name 'get_Constraints' is not defined
# [NMPC] t=204, u_first=[0.000, 8.158], angle=-99.186, ang_vel=-52.050
# [NMPC] get_Constraints failed at t=205, it=0: name 'get_Constraints' is not defined
# [NMPC] t=205, u_first=[0.000, 8.158], angle=-101.268, ang_vel=-52.557
# [NMPC] get_Constraints failed at t=206, it=0: name 'get_Constraints' is not defined
# [NMPC] t=206, u_first=[0.000, 8.158], angle=-103.370, ang_vel=-53.065
# [NMPC] get_Constraints failed at t=207, it=0: name 'get_Constraints' is not defined
# [NMPC] t=207, u_first=[0.000, 8.158], angle=-105.493, ang_vel=-53.572
# [NMPC] get_Constraints failed at t=208, it=0: name 'get_Constraints' is not defined
# [NMPC] t=208, u_first=[0.000, 8.158], angle=-107.636, ang_vel=-54.080
# [NMPC] get_Constraints failed at t=209, it=0: name 'get_Constraints' is not defined
# [NMPC] t=209, u_first=[0.000, 8.158], angle=-109.799, ang_vel=-54.588
# [NMPC] get_Constraints failed at t=210, it=0: name 'get_Constraints' is not defined
# [NMPC] t=210, u_first=[0.000, 8.158], angle=-111.982, ang_vel=-55.095
# [NMPC] get_Constraints failed at t=211, it=0: name 'get_Constraints' is not defined
# [NMPC] t=211, u_first=[0.000, 8.158], angle=-114.186, ang_vel=-55.603
# [NMPC] get_Constraints failed at t=212, it=0: name 'get_Constraints' is not defined
# [NMPC] t=212, u_first=[0.000, 8.158], angle=-116.410, ang_vel=-56.110
# [NMPC] get_Constraints failed at t=213, it=0: name 'get_Constraints' is not defined
# [NMPC] t=213, u_first=[0.000, 8.158], angle=-118.655, ang_vel=-56.618
# [NMPC] get_Constraints failed at t=214, it=0: name 'get_Constraints' is not defined
# [NMPC] t=214, u_first=[0.000, 8.158], angle=-120.919, ang_vel=-57.126
# [NMPC] get_Constraints failed at t=215, it=0: name 'get_Constraints' is not defined
# [NMPC] t=215, u_first=[0.000, 8.158], angle=-123.204, ang_vel=-57.633
# [NMPC] get_Constraints failed at t=216, it=0: name 'get_Constraints' is not defined
# [NMPC] t=216, u_first=[0.000, 8.158], angle=-125.510, ang_vel=-58.141
# [NMPC] get_Constraints failed at t=217, it=0: name 'get_Constraints' is not defined
# [NMPC] t=217, u_first=[0.000, 8.158], angle=-127.835, ang_vel=-58.648
# [NMPC] get_Constraints failed at t=218, it=0: name 'get_Constraints' is not defined
# [NMPC] t=218, u_first=[0.000, 8.158], angle=-130.181, ang_vel=-59.156
# [NMPC] get_Constraints failed at t=219, it=0: name 'get_Constraints' is not defined
# [NMPC] t=219, u_first=[0.000, 8.158], angle=-132.548, ang_vel=-59.664
# [NMPC] get_Constraints failed at t=220, it=0: name 'get_Constraints' is not defined
# [NMPC] t=220, u_first=[0.000, 8.158], angle=-134.934, ang_vel=-60.171
# [NMPC] get_Constraints failed at t=221, it=0: name 'get_Constraints' is not defined
# [NMPC] t=221, u_first=[0.000, 8.158], angle=-137.341, ang_vel=-60.679
# [NMPC] get_Constraints failed at t=222, it=0: name 'get_Constraints' is not defined
# [NMPC] t=222, u_first=[0.000, 8.158], angle=-139.768, ang_vel=-61.186
# [NMPC] get_Constraints failed at t=223, it=0: name 'get_Constraints' is not defined
# [NMPC] t=223, u_first=[0.000, 8.158], angle=-142.215, ang_vel=-61.694
# [NMPC] get_Constraints failed at t=224, it=0: name 'get_Constraints' is not defined
# [NMPC] t=224, u_first=[0.000, 8.158], angle=-144.683, ang_vel=-62.202
# [NMPC] get_Constraints failed at t=225, it=0: name 'get_Constraints' is not defined
# [NMPC] t=225, u_first=[0.000, 8.158], angle=-147.171, ang_vel=-62.709
# [NMPC] get_Constraints failed at t=226, it=0: name 'get_Constraints' is not defined
# [NMPC] t=226, u_first=[0.000, 8.158], angle=-149.680, ang_vel=-63.799
# [NMPC] get_Constraints failed at t=227, it=0: name 'get_Constraints' is not defined
# [NMPC] t=227, u_first=[0.000, 8.158], angle=-152.232, ang_vel=-64.307
# [NMPC] get_Constraints failed at t=228, it=0: name 'get_Constraints' is not defined
# [NMPC] t=228, u_first=[0.000, 8.158], angle=-154.804, ang_vel=-64.814
# [NMPC] get_Constraints failed at t=229, it=0: name 'get_Constraints' is not defined
# [NMPC] t=229, u_first=[0.000, 8.158], angle=-157.397, ang_vel=-65.322
# [NMPC] get_Constraints failed at t=230, it=0: name 'get_Constraints' is not defined
# [NMPC] t=230, u_first=[0.000, 8.158], angle=-160.009, ang_vel=-65.830
# [NMPC] get_Constraints failed at t=231, it=0: name 'get_Constraints' is not defined
# [NMPC] t=231, u_first=[0.000, 8.158], angle=-162.643, ang_vel=-66.337
# [NMPC] get_Constraints failed at t=232, it=0: name 'get_Constraints' is not defined
# [NMPC] t=232, u_first=[0.000, 8.158], angle=-165.296, ang_vel=-66.845
# [NMPC] get_Constraints failed at t=233, it=0: name 'get_Constraints' is not defined
# [NMPC] t=233, u_first=[0.000, 8.158], angle=-167.970, ang_vel=-67.352
# [NMPC] get_Constraints failed at t=234, it=0: name 'get_Constraints' is not defined
# [NMPC] t=234, u_first=[0.000, 8.158], angle=-170.664, ang_vel=-67.860
# [NMPC] get_Constraints failed at t=235, it=0: name 'get_Constraints' is not defined
# [NMPC] t=235, u_first=[0.000, 8.158], angle=-173.378, ang_vel=-68.368
# [NMPC] get_Constraints failed at t=236, it=0: name 'get_Constraints' is not defined
# [NMPC] t=236, u_first=[0.000, 8.158], angle=-176.113, ang_vel=-68.875
# [NMPC] get_Constraints failed at t=237, it=0: name 'get_Constraints' is not defined
# [NMPC] t=237, u_first=[0.000, 8.158], angle=-178.868, ang_vel=-69.383
# [NMPC] get_Constraints failed at t=238, it=0: name 'get_Constraints' is not defined
# [NMPC] t=238, u_first=[0.000, 8.158], angle=-181.643, ang_vel=-69.890
# [NMPC] get_Constraints failed at t=239, it=0: name 'get_Constraints' is not defined
# [NMPC] t=239, u_first=[0.000, 8.158], angle=-184.439, ang_vel=-70.398
# [NMPC] get_Constraints failed at t=240, it=0: name 'get_Constraints' is not defined
# [NMPC] t=240, u_first=[0.000, 8.158], angle=-187.255, ang_vel=-70.906
# [NMPC] get_Constraints failed at t=241, it=0: name 'get_Constraints' is not defined
# [NMPC] t=241, u_first=[0.000, 8.158], angle=-190.091, ang_vel=-71.413
# [NMPC] get_Constraints failed at t=242, it=0: name 'get_Constraints' is not defined
# [NMPC] t=242, u_first=[0.000, 8.158], angle=-192.948, ang_vel=-71.921
# [NMPC] get_Constraints failed at t=243, it=0: name 'get_Constraints' is not defined
# [NMPC] t=243, u_first=[0.000, 8.158], angle=-195.825, ang_vel=-72.428
# [NMPC] get_Constraints failed at t=244, it=0: name 'get_Constraints' is not defined
# [NMPC] t=244, u_first=[0.000, 8.158], angle=-198.722, ang_vel=-72.936
# [NMPC] get_Constraints failed at t=245, it=0: name 'get_Constraints' is not defined
# [NMPC] t=245, u_first=[0.000, 8.158], angle=-201.639, ang_vel=-73.444
# [NMPC] get_Constraints failed at t=246, it=0: name 'get_Constraints' is not defined
# [NMPC] t=246, u_first=[0.000, 8.158], angle=-204.577, ang_vel=-73.951
# [NMPC] get_Constraints failed at t=247, it=0: name 'get_Constraints' is not defined
# [NMPC] t=247, u_first=[0.000, 8.158], angle=-207.535, ang_vel=-74.459
# [NMPC] get_Constraints failed at t=248, it=0: name 'get_Constraints' is not defined
# [NMPC] t=248, u_first=[0.000, 8.158], angle=-210.513, ang_vel=-74.966
# [NMPC] get_Constraints failed at t=249, it=0: name 'get_Constraints' is not defined
# [NMPC] t=249, u_first=[0.000, 8.158], angle=-213.512, ang_vel=-75.474
# NMPC simulation finished.
# Final height: -187.1237429181677
# Min height: -187.1237429181677 Max height: 0.0
# <video width="850" height="850" controls autoplay loop>
#   <source type="video/mp4" src="...
